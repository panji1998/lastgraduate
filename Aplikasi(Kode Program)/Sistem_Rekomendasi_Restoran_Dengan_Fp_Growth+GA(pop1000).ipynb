# %% [markdown]
# # Tugas Akhir TA-11 Sistem Informasi T.A. 2019/2020
# - Association Analysis using Frequent Pattern Growth-Genetic Algorithm for Restaurant Recommendation System
# - (12S16013) Panji Jonatan Situmorang dan (12S16051) Hesti Rugun Juli Arta Siagian
# - Notebook ini ditujukan untuk mendemonstrasikan sistem yang dirancang.

# %% [markdown]
# ## 1. Muat Pustaka Python

# %%
import ast
import math
import numpy as np
import pandas as pd
import random
import re
import time

# Gunakan modul fpgrowth dalam mlxtend library untuk melakukan
# FP-Growth
try:
    import mlxtend
    from mlxtend.preprocessing import TransactionEncoder
    from mlxtend.frequent_patterns import fpgrowth
    from mlxtend.frequent_patterns import association_rules
except:
    # %pip install mlxtend --upgrade
    import mlxtend
    from mlxtend.preprocessing import TransactionEncoder
    from mlxtend.frequent_patterns import fpgrowth
    from mlxtend.frequent_patterns import association_rules

# Gunakan deap library untuk melakukan
# Genetic Algorithm
try:
    # Gunakan deap library untuk melakukan
    # Genetic Algorithm
    from deap import base
    from deap import creator
    from deap import tools
except:
    # %pip install deap --upgrade
    from deap import base
    from deap import creator
    from deap import tools

# %% [markdown]
# ## 2. Muat Data

# %% [markdown]
# Pada _cell_ berikut ini dilakukan pembacaan set data **"Restaurant reviews"** dan **"Restaurant names and Metadata.csv"**. Keduanya digabungkan dan disimpan dalam struktur data _DataFrame_ bernama <code>df_tr_restoran</code>.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Menyimpan set data review restoran dalam DataFrame df_review_restoran
df_review_restoran = pd.read_csv("/content/drive/MyDrive/Restaurant reviews.csv",
                                 usecols = ["Restaurant", "Reviewer", "Rating"])

# Menyimpan set data metadata restoran dalam DataFrame df_md_restoran
df_md_restoran = pd.read_csv("/content/drive/MyDrive/Restaurant names and Metadata.csv",
                             usecols = ["Name", "Cuisines"])

# Menyimpan gabungan df_review_restoran dan df_md_restoran dalam DataFrame df_tr_restoran
df_tr_restoran = df_md_restoran.merge(df_review_restoran,
                                      left_on = "Name",
                                      right_on = "Restaurant",
                                      how = "inner").drop(["Name"], axis = 1)

# Ganti nama kolom "Restaurant" menjadi "Preferred Restaurant"
df_tr_restoran = df_tr_restoran.rename(columns={"Restaurant": "Preferred Restaurant"})

# %% [markdown]
# ## 3. Prapemrosesan

# %%
# Hapus baris data yang memiliki setidaknya satu nilai atribut hilang (NaN / None)
df_tr_restoran = df_tr_restoran.dropna(axis = 0, how ='any')
df_tr_restoran = df_tr_restoran.reset_index(drop=True)

# %%
# Pastikan tipe data Rating adalah numerik 
df_tr_restoran['Rating'] = pd.to_numeric(df_tr_restoran['Rating'], errors='coerce')

# Pilih restoran dengan rating baik (rating >= 3)
df_tr_restoran = df_tr_restoran[df_tr_restoran['Rating'] >= 3]
df_tr_restoran = df_tr_restoran.drop(['Rating'], axis=1)
df_tr_restoran = df_tr_restoran.reset_index(drop=True)

# %%
# Pengelompokkan restoran berdasarkan reviewer
df_tr_restoran = df_tr_restoran.groupby(by = ["Reviewer"])["Preferred Restaurant"].apply(list).reset_index()
display(df_tr_restoran.head())
# Out:
#                       Reviewer               Preferred Restaurant
# 0                    #FOODPORN  [Zega - Sheraton Hyderabad Hotel]
# 1          #chloesviews // CAH                          [eat.fit]
# 2                         $ign                            [SKYHY]
# 3  @FuloriBinaChutneyKaiseBani                 [Chinese Pavilion]
# 4            @Vignesh #FoodMad                      [Owm Nom Nom]

# %%
# Pengkodean Label pada nama restoran  
# Simpan set pemetaan dalam restaurant_replace_map_comp
restaurant_labels = np.unique(np.concatenate([np.unique(row) for row in df_tr_restoran['Preferred Restaurant']])).tolist()
restaurant_replace_map_comp = {v: k for k, v in zip(list(range(1,len(restaurant_labels)+1)), restaurant_labels)}

# Ganti setiap nama restoran dengan indeks yang sesuai 
for i, row in df_tr_restoran.iterrows():
    res = [restaurant_replace_map_comp.get(ele, ele) for ele in row['Preferred Restaurant']]
    df_tr_restoran.at[i, 'Preferred Restaurant'] = np.array(res)

# %%
display(df_tr_restoran.tail())
# Out:
#                  Reviewer Preferred Restaurant
# 5626  విజయ్ కుమార్ తెజవత్                 [44]
# 5627       ಅಭಿಷೇಕ್ ಉಪಾಧ್ಯ                 [80]
# 5628        ✌️✌️Reddy 🥂🍽️                 [47]
# 5629              ✔️ Sonu                 [76]
# 5630                  🍛🍲🥗             [67, 34]

# %%
# Simpan hasil prapemrosesan dalam Numpy Array np_transaksi_restoran
np_transaksi_restoran = df_tr_restoran['Preferred Restaurant'].to_numpy()

# %% [markdown]
# ## 4. Penerapan FP-Growth

# %%
dataset = df_tr_restoran['Preferred Restaurant'].tolist()

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
display(df.tail())
# Out:
#         1      2      3      4      5    ...    96     97     98     99     100
# 5626  False  False  False  False  False  ...  False  False  False  False  False
# 5627  False  False  False  False  False  ...  False  False  False  False  False
# 5628  False  False  False  False  False  ...  False  False  False  False  False
# 5629  False  False  False  False  False  ...  False  False  False  False  False
# 5630  False  False  False  False  False  ...  False  False  False  False  False
#
# [5 rows x 100 columns]

# %%
# minimal 2 kali dari seluruh transaksi
df_frequent_itemsets = fpgrowth(df, min_support=(2/len(df)), max_len=2, use_colnames=True)

# %%
df_rules = association_rules(df_frequent_itemsets, metric="confidence", min_threshold=(2/len(df)))
# df_rules = association_rules(df_frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
df_rules.tail()
# Out:
#      antecedents consequents  ...  leverage  conviction
# 1709        (61)        (67)  ...  0.000234    1.018287
# 1710        (26)        (67)  ...  0.000216    1.014639
# 1711        (67)        (26)  ...  0.000216    1.024301
# 1712        (67)        (95)  ...  0.000245    1.027626
# 1713        (95)        (67)  ...  0.000245    1.021250
#
# [5 rows x 9 columns]

# %%
# Fungsi _Encoding_ dan _Decoding_ pada Aturan Asosiasi
# Michigan Encoding
def michigan_encoding(df_association_rules, list_items):
    list_encoded_association_rules = []

    for tuple_rule in df_association_rules.itertuples():
        list_encoded_rule = []
        
        for item in list_items:
            if item in tuple_rule.antecedents:
                list_encoded_rule.append('01')
            elif item in tuple_rule.consequents:
                list_encoded_rule.append('10')
            else:
                list_encoded_rule.append('00')
        list_encoded_association_rules.append(list_encoded_rule)
    return list_encoded_association_rules

# Michigan Decoding
def michigan_decoding(list_encoded_association_rules, list_items):
    list_rules = []
    
    for encoded_rule in list_encoded_association_rules:
        antecedent = []
        consequent = []

        for idx, ele in enumerate(encoded_rule):
            if ele == '01':
                antecedent.append(list_items[idx])
            elif ele == '10':
                consequent.append(list_items[idx])
        list_rules.append([antecedent, consequent, encoded_rule])
    
    return pd.DataFrame(list_rules, columns=['antecedents', 'consequents', 'chromosome'])

# %% [markdown]
# Jalankan _encoding_.

# %%
list_encoded_association_rules = michigan_encoding(df_rules, [*restaurant_replace_map_comp.values()])

# %%
# cuplikan aturan asosiasi yang telah di-encode 
for index, rule in enumerate(list_encoded_association_rules):
    print(index, ":", str(rule))
    if index == 1:
        break
# Out:
# 0 : ['00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '10', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '01']
# 1 : ['00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '01', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '10']

# %% [markdown]
# ## 5. Penerapan Genetic Algorithm

# %% [markdown]
# **Creator**
#
# Karena struktur aktual individu yang diperlukan dalam _genetic algorithm_ sangat bergantung pada kasus yang akan diselesaikan, maka DEAP _library_ tidak menyediakan struktur eksplisit apa pun. Namun, DEAP _library_ menyediakan _method_ untuk membuat wadah bagi atribut, terkait dengan _fitness_. _Method_ ini disebut <code>deap.creator</code>.
#
# <code>creator</code> adalah "pabrik kelas" yang dapat kita gunakan untuk membuat kelas baru pada saat program dijalankan. Pemanggilannya dilengkapi dengan beberapa argumen. Argumen pertama yaitu nama yang diinginkan dari kelas baru yang akan dibuat, argumen kedua adalah kelas dasar yang akan diwarisi, dan argumen berikutnya adalah atribut kelas baru yang dibuat.
#
# Pada _cell_ berikut ini, kita mendefinisikan sebuah kelas bernama **"FitnessMax"**. Kelas ini akan mewarisi kelas **"Fitness"** dari modul <code>deap.base</code>. Kelas ini juga akan memiliki atribut tambahan yang disebut **"weights"**. Perhatikan bahwa nilai **"weights"** disajikan dengan bentuk _tuple_ (1.0,). Dengan cara ini, kita secara eksplisit menyatakan bahwa kasus optimasi yang dikerjakan adalah memaksimalkan _fitness_ objektif tunggal.

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))

# %% [markdown]
# Selanjutnya, kita buat kelas bernama **"Individual"**, yang akan mewarisi kelas **"list"** dan mengandung kelas **"FitnessMax"** yang telah kita definisikan sebelumnya dalam atribut **"fitness"**.

# %%
creator.create("Individual", list, fitness=creator.FitnessMax)

# %% [markdown]
# **Toolbox**

# %%
toolbox = base.Toolbox()

# %% [markdown]
# **Evaluation Function**
#
# - $ \mathrm{support}(A->C) = \mathrm{support}(A \cup C)$, range: [0, 1]
#
#
#
# - $ \mathrm{confidence}(A->C) = \frac{\mathrm{support}(A \cup C)}{\mathrm{support}(A)}$, range: [0, 1]
#
#
#
# - $ \mathrm{lift}(A->C) = \frac{\mathrm{confidence}(A->C)}{\mathrm{support}(C)}$, range: [0, inf]
#
#
#
# - $ \mathrm{kulczynski}(A->C) = \frac{1}{2} (\frac{\mathrm{support}(A \cup C)}{\mathrm{support}(A)} + \frac{\mathrm{support}(A \cup C)}{\mathrm{support}(C)}) $, range: [0, 1]

# %%
def safe_div(x,y):
    if y==0: return 0
    return x/y

def kulczynski(encoded_rule, np_data_transaksi, list_items):
    antecedent = []
    consequent = []

    for idx, ele in enumerate(encoded_rule):
        if ele == '01':
            antecedent.append(list_items[idx])
        elif ele == '10':
            consequent.append(list_items[idx])
    decoded_rule = antecedent + consequent

    support_rule = [bool(set(decoded_rule) and set(decoded_rule).issubset(set(sublist))) \
                    for sublist in np_data_transaksi].count(True) / len(np_data_transaksi)
    support_antecedent = [bool(set(antecedent) and set(antecedent).issubset(set(sublist))) \
                    for sublist in np_data_transaksi].count(True) / len(np_data_transaksi)
    support_consequent = [bool(set(consequent) and set(consequent).issubset(set(sublist))) \
                    for sublist in np_data_transaksi].count(True) / len(np_data_transaksi)
    kulczynski_rule = (1/2) * (safe_div(support_rule, support_antecedent) + safe_div(support_rule, support_consequent))
    
    return kulczynski_rule

def evalOneMax(individual):
    return kulczynski(individual, np_transaksi_restoran, [*restaurant_replace_map_comp.values()]),

# %% [markdown]
# **The Genetic Operators**

# %%
#----------
# Registrasi Operator Genetik
#----------
# Registrasi tujuan / fungsi fitness 'evalOneMax'
toolbox.register("evaluate", evalOneMax)

# Registrasi operator crossover dengan
# teknik one point crossover
toolbox.register("mate", tools.cxOnePoint)

# Registrasi operator mutation dengan teknik DNA shuffling
# dan probabilitas setiap DNA dipindahkan
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.05)

# Registrasi operator dengan teknik tournament selection 
# untuk memilih individu-individu di generasi selanjutnya
# di mana setiap individu dari generasi sebelumnya digantikan
# dengan 2 individu dari generasi saat ini
toolbox.register("select", tools.selTournament, tournsize=2)

#----------

# %% [markdown]
# **Creating the Population**

# %%
mins=[]
maxs=[]
means=[]
stds=[]

def main(): 
    pop = []
    # Konversi struktur data setiap kromosom dari 'list'
    # menjadi 'deap.creator.Individual' supaya dapat
    # digunakan di algoritma GA dalam DEAP library
    for rule in list_encoded_association_rules:
        pop.append(creator.Individual(rule))
    
    # CXPB adalah probabilitas dua individu
    # disilangkan
    #
    # MUTPB adalah probabilitas sebuah individu
    # mengalami mutasi
    CXPB, MUTPB = 0.5, 0.2

    print('Start of evolution')

    # Hitung nilai fitness seluruh individu dalam populasi
    # dengan menggunakan 'evalOneMax' yang sudah disimpan
    # dalam 'toolbox.evaluate' di cell 
    # 'Registrasi Operator Genetik'
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit

    print('  Evaluated %i individuals' % len(pop))

    # Ekstraksi nilai fitness setiap individu 'ind'
    # dalam populasi 'pop' dan simpan dalam list 'fits'
    fits = [ind.fitness.values[0] for ind in pop]
    
    length = len(pop)
    mean = sum(fits) / length
    sum2 = sum(x*x for x in fits)
    std = abs(sum2 / length - mean*2)*0.5
        
    mins.append(min(fits))
    maxs.append(max(fits))
    means.append(mean)
    stds.append(std)
    
    print('  Min %s' % min(fits))
    print('  Max %s' % max(fits))
    print('  Avg %s' % mean)
    print('  Std %s' % std)        
    
    # Variabel 'g' untuk pemantauan total generasi
    # di mana satu generasi sama dengan satu iterasi
    g = 0

    # Lakukan evolusi selama generasi 'g'
    # lebih kecil dari 1000
    while g < 1000:
        # Sebuah generasi baru
        g = g + 1
        print('-- Generation %i --' % g)

        # Pilih individu-individu untuk generasi selanjutnya
        offspring = toolbox.select(pop, len(pop))
        # Kloning individu-individu yang terpilih
        offspring = list(map(toolbox.clone, offspring))

        # Terapkan penyilangan dan mutation pada  
        # individu yang merupakan anakan 'offspring'
        for child1, child2 in zip(offspring[::2], offspring[1::2]):

            # Silangkan dua individu dengan menggunakan 
            # CXPB
            if random.random() < CXPB:
                toolbox.mate(child1, child2)

                # Hapus nilai fitness value hasil
                # persilangan karena invalid
                del child1.fitness.values
                del child2.fitness.values

        for mutant in offspring:

            # Mutasi sebuah individu dengan menggunakan
            # MUTPB
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Kalkulasi ulang nilai fitness individu-individu
        # 'offspring'
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        print('  Evaluated %i individuals' % len(invalid_ind))

        # Gantikan populasi seutuhnya dengan menggunakan 
        # offspring
        pop[:] = offspring

        # Kumpulkan semua fitness dalam sebuah list 
        # dan untuk ditampilkan statistiknya seperti
        # min, max, rata-rata, dan standar deviasi
        fits = [ind.fitness.values[0] for ind in pop]

        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean*2)*0.5
        
        mins.append(min(fits))
        maxs.append(max(fits))
        means.append(mean)
        stds.append(std)
        
        print('  Min %s' % min(fits))
        print('  Max %s' % max(fits))
        print('  Avg %s' % mean)
        print('  Std %s' % std)

    print('-- End of (successful) evolution --')
    print('\n')
    
    # Tampilkan populasi akhir
    print('-- Final Population --')
    df_fits = pd.DataFrame(fits, columns =['kulczynski']) 
    df_pop = michigan_decoding(pop, [*restaurant_replace_map_comp.values()])
    df_pop = pd.concat([df_pop, df_fits], axis=1)
    print('\n')
    
    return df_pop

if __name__ == '__main__':
    df_hasil = main()
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
#   Avg 0.9231453481683567
#   Std 0.4618461137632904
# -- Generation 169 --
#   Evaluated 1063 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9179071979388157
#   Std 0.45955516968232357
# -- Generation 170 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.930308618703275
#   Std 0.465664710843739
# -- Generation 171 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9348173284739231
#   Std 0.46786441613544827
# -- Generation 172 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9260542836951698
#   Std 0.463154752818024
# -- Generation 173 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9317429130345254
#   Std 0.46605376279913435
# -- Generation 174 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9362687898963554
#   Std 0.46833491766361307
# -- Generation 175 --
#   Evaluated 992 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9364144662746193
#   Std 0.46835306054131237
# -- Generation 176 --
#   Evaluated 988 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9203794742286722
#   Std 0.4605907762720494
# -- Generation 177 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.934524695641894
#   Std 0.46764515934618256
# -- Generation 178 --
#   Evaluated 1055 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9215536351580447
#   Std 0.4613601383043628
# -- Generation 179 --
#   Evaluated 998 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9254927415982713
#   Std 0.46316559279367037
# -- Generation 180 --
#   Evaluated 1054 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9291131855309218
#   Std 0.4646659859976663
# -- Generation 181 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9295607223285778
#   Std 0.46509026543870186
# -- Generation 182 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9351010150609667
#   Std 0.4677510364763456
# -- Generation 183 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9327674740385952
#   Std 0.46658426466048963
# -- Generation 184 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9307176196032673
#   Std 0.4655228996499417
# -- Generation 185 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.93043151422673
#   Std 0.4654527488124252
# -- Generation 186 --
#   Evaluated 1054 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9323261623416109
#   Std 0.4663453887573473
# -- Generation 187 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.941365227537923
#   Std 0.47079200700116686
# -- Generation 188 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.943560758351515
#   Std 0.472090301353825
# -- Generation 189 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0
--
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9410770697555284
#   Std 0.4707208460853926
# -- Generation 230 --
#   Evaluated 1053 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9350280862394964
#   Std 0.46794703268404686
# -- Generation 231 --
#   Evaluated 1019 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.929992440054563
#   Std 0.46517852761382333
# -- Generation 232 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9243131593927143
#   Std 0.4626214486493311
# -- Generation 233 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9152666092915939
#   Std 0.4578338161623181
# -- Generation 234 --
#   Evaluated 1061 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9221299545771172
#   Std 0.46146601543452564
# -- Generation 235 --
#   Evaluated 1043 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9298521923209665
#   Std 0.4651266089816746
# -- Generation 236 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9270795771264281
#   Std 0.4636856159672168
# -- Generation 237 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9167193945469785
#   Std 0.4587060947083391
# -- Generation 238 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.923877272826198
#   Std 0.46233969662123986
# -- Generation 239 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9158578872975168
#   Std 0.4581339780470793
# -- Generation 240 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.924764370929717
#   Std 0.462755821394373
# -- Generation 241 --
#   Evaluated 994 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9343831279296283
#   Std 0.46745128378032363
# -- Generation 242 --
#   Evaluated 1081 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9439233461987253
#   Std 0.4721576423363459
# -- Generation 243 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9245915985997666
#   Std 0.462350495915986
# -- Generation 244 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.935904145789004
#   Std 0.46827566299616835
# -- Generation 245 --
#   Evaluated 995 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9288257601757156
#   Std 0.4645951863697295
# -- Generation 246 --
#   Evaluated 1088 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9205075845974329
#   Std 0.4603084889148191
# -- Generation 247 --
#   Evaluated 949 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9280921820303384
#   Std 0.4641007876312719
# -- Generation 248 --
#   Evaluated 1062 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9295507584597433
#   Std 0.46493946907817973
# -- Generation 249 --
#   Evaluated 1039 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9355309218203034
#   Std 0.4678748541423571
# -- Generation 250 --
#   Evaluated 992 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9416610514898023
#   Std 0.47101283333144295
# -- Generation 251 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9324720199845514
#   Std 0.4663636209627149
# -- Generation 252 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9343640606767795
#   Std 0.4672914235705951
# -- Generation 253 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9362644999656806
#   Std 0.4683692528808147
# -- Generation 254 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9412305897136702
#   Std 0.47092518840664765
# -- Generation 255 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9250291715285881
#   Std 0.46262397899649943
# -- Generation 256 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.920821706986004
#   Std 0.4608301067678625
# -- Generation 257 --
#   Evaluated 1012 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.927230863414036
#   Std 0.46388885888254594
# -- Generation 258 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9214792089475121
#   Std 0.461300165228179
# -- Generation 259 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9245227784442948
#   Std 0.4625120675788176
# -- Generation 260 --
#   Evaluated 1103 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9288296875770375
#   Std 0.4645606724971917
# -- Generation 261 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9388211173831376
#   Std 0.4697341500979053
# -- Generation 262 --
#   Evaluated 995 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9336474609894249
#   Std 0.4670971675644842
# -- Generation 263 --
#   Evaluated 1060 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9314469078179697
#   Std 0.4658328471411902
# -- Generation 264 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9275255850408912
#   Std 0.464109141292483
# -- Generation 265 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9179017654398649
#   Std 0.45940660367374775
# -- Generation 266 --
#   Evaluated 997 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9276686176075339
#   Std 0.4641624312907274
# -- Generation 267 --
#   Evaluated 994 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9344517668204239
#   Std 0.46762236908947324
# -- Generation 268 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9217585943811147
#   Std 0.4612210970997631
# -- Generation 269 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9278922815541002
#   Std 0.46436084419454526
# -- Generation 270 --
#   Evaluated 1081 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.
individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9305758706263251
#   Std 0.4656616810560637
# -- Generation 552 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9377960052165558
#   Std 0.46920337627638065
# -- Generation 553 --
#   Evaluated 1069 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.922408023886334
#   Std 0.46138631822503867
# -- Generation 554 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9393961493582264
#   Std 0.4698758386814469
# -- Generation 555 --
#   Evaluated 1064 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9224134525310015
#   Std 0.46157132893500025
# -- Generation 556 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9222733899163646
#   Std 0.46148305492913394
# -- Generation 557 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9285297549591599
#   Std 0.46437427071178533
# -- Generation 558 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.929928678645923
#   Std 0.46530614088970423
# -- Generation 559 --
#   Evaluated 999 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9270146843722781
#   Std 0.4639595585669506
# -- Generation 560 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9308028744227325
#   Std 0.4658526408928121
# -- Generation 561 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9300006573865598
#   Std 0.4653284649884946
# -- Generation 562 --
#   Evaluated 1023 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9353891728433612
#   Std 0.4680409838565305
# -- Generation 563 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9228497054811539
#   Std 0.46162537676068244
# -- Generation 564 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9246315755662432
#   Std 0.4630070473283197
# -- Generation 565 --
#   Evaluated 1007 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9256288481311842
#   Std 0.4632154757268896
# -- Generation 566 --
#   Evaluated 1019 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.93466773206282
#   Std 0.4676620046430412
# -- Generation 567 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9315963229643965
# ...
#   Min 0.0
#   Max 1.0
#   Avg 0.9318887706774659
#   Std 0.46607199500450197
# -- Generation 869 --
#   Evaluated 1038 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9334283119956613
#   Std 0.4670559664470711
# -- Generation 870 --
#   Evaluated 1021 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9237349324434918
#   Std 0.46232319706980507
# -- Generation 871 --
#   Evaluated 943 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9301470588235295
#   Std 0.4653469651768664
# -- Generation 872 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9288293176792018
#   Std 0.46456048986469023
# -- Generation 873 --
#   Evaluated 1064 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9269537004282014
#   Std 0.46396900273037317
# -- Generation 874 --
#   Evaluated 1066 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9413738073992725
#   Std 0.4709421230311742
# -- Generation 875 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9361264897569012
#   Std 0.4682819889532062
# -- Generation 876 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9355395016816528
#   Std 0.46802497017236433
# -- Generation 877 --
#   Evaluated 1001 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9340723453908985
#   Std 0.46725495915985993
# -- Generation 878 --
#   Evaluated 1061 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9310179147504977
#   Std 0.46570948009068414
# -- Generation 879 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9288257601757156
#   Std 0.4648139728341402
# -- Generation 880 --
#   Evaluated 1039 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9203695743886535
#   Std 0.4604400114516215
# -- Generation 881 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9276546091015169
#   Std 0.46404609101516914
# -- Generation 882 --
#   Evaluated 1053 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9195694097583385
#   Std 0.4601082837819216
# -- Generation 883 --
#   Evaluated 999 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9251884865150335
#   Std 0.4629770659816663
# -- Generation 884 --
#   Evaluated 1059 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.933497494680486
#   Std 0.46707689549325127
# -- Generation 885 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9349515999145398
#   Std 0.4675487143116064
# -- Generation 886 --
#   Evaluated 1069 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9297106246087008
#   Std 0.4650740415591055
# -- Generation 887 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9355344793237897
#   Std 0.4678401576373179
# -- Generation 888 --
#   Evaluated 1020 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9358269270368591
#   Std 0.4680957698003012
# -- Generation 889 --
#   Evaluated 997 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9374427660468518
#   Std 0.4690025024342402
# -- Generation 890 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.925470301960896
#   Std 0.46308155203638446
# -- Generation 891 --
#   Evaluated 1065 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9262052000849423
#   Std 0.4633578131008519
# -- Generation 892 --
#   Evaluated 989 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9364887150747588
#   Std 0.46856793774480193
# -- Generation 893 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9221155761732647
#   Std 0.4613494925264661
# -- Generation 894 --
#   Evaluated 983 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9281778357681253
#   Std 0.4644307230718921
# -- Generation 895 --
#   Evaluated 1006 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9272383409503615
#   Std 0.4640384309922144
# -- Generation 896 --
#   Evaluated 1015 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9320542869790193
#   Std 0.46643298696682267
# -- Generation 897 --
#   Evaluated 976 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9326244414719527
#   Std 0.46653097466224547
# -- Generation 898 --
#   Evaluated 1003 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9232824373167886
#   Std 0.4617141366338174
# -- Generation 899 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9387519273298299
#   Std 0.4697041009718759
# -- Generation 900 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9310863723766167
#   Std 0.4657391679288759
# -- Generation 901 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9352560401167374
#   Std 0.4681384586787143
# -- Generation 902 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9242269544924154
#   Std 0.4622365446324388
# -- Generation 903 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9316095990432252
#   Std 0.4661511482936501
# -- Generation 904 --
#   Evaluated 1083 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9255475207130408
#   Std 0.46304265876784073
# -- Generation 905 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9312464561792194
#   Std 0.46609263174429405
# -- Generation 906 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9434186394767373
#   Std 0.4720374619710864
# -- Generation 907 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9301382976975036
#   Std 0.46519675981919095
# -- Generation 908 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9367048979708
#   Std 0.4686076781684515
# -- Generation 909 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9198547827076871
#   Std 0.46017807333160027
# -- Generation 910 --
#   Evaluated 993 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9243258804547476
#   Std 0.4625821622219087
# -- Generation 911 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9332231966741175
#   Std 0.46719491017990156
# -- Generation 912 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9395623942326848
#   Std 0.47041467449466406
# -- Generation 913 --
#   Evaluated 1102 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9359321953357234
#   Std 0.4687635902554946
# -- Generation 914 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9352526638779273
#   Std 0.4679544580470106
# -- Generation 915 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9253379016614603
#   Std 0.4631520398383541
# -- Generation 916 --
#   Evaluated 1062 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9265749067934086
#   Std 0.46375688930073017
# -- Generation 917 --
#   Evaluated 1057 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9258448459082659
#   Std 0.46326422321620564
# -- Generation 918 --
#   Evaluated 987 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.92593592829072
#   Std 0.46358773121042773
# -- Generation 919 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9417390390581045
#   Std 0.4711931033575613
# -- Generation 920 --
#   Evaluated 990 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9390315052508752
#   Std 0.469625145857643
# -- Generation 921 --
#   Evaluated 995 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9403442240373395
#   Std 0.47022680863477245
# -- Generation 922 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9439906651108518
#   Std 0.4719953325554259
# -- Generation 923 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9363553646944897
#   Std 0.4688840941613146
# -- Generation 924 --
#   Evaluated 1086 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.938745399874338
#   Std 0.46955499502012665
# -- Generation 925 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.93254905747202
#   Std 0.466543424830914
# -- Generation 926 --
#   Evaluated 1019 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9282423296039537
#   Std 0.46430347108384856
# -- Generation 927 --
#   Evaluated 1019 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9336444910374191
#   Std 0.4671321515721062
# -- Generation 928 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9399066511085181
#   Std 0.46995332555425906
# -- Generation 929 --
#   Evaluated 993 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9248945375586186
#   Std 0.4627207157005945
# -- Generation 930 --
#   Evaluated 1001 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.925984361214674
#   Std 0.4633157805605168
# -- Generation 931 --
#   Evaluated 1020 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9304406854938436
#   Std 0.4655667076436301
# -- Generation 932 --
#   Evaluated 1089 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9375891748523044
#   Std 0.46908624585524433
# -- Generation 933 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9361255760650364
#   Std 0.4682815383377008
# -- Generation 934 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9321833110396448
#   Std 0.46629218808677114
# -- Generation 935 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9248911613198088
#   Std 0.4627555015333018
# -- Generation 936 --
#   Evaluated 1067 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9355380368272761
#   Std 0.46824303406110024
# -- Generation 937 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9337997012121497
#   Std 0.4672644319363468
# -- Generation 938 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9447235108290406
#   Std 0.472489370006046
# -- Generation 939 --
#   Evaluated 1057 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9337954112814749
#   Std 0.46729876715354846
# -- Generation 940 --
#   Evaluated 1083 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9247488611803545
#   Std 0.46270257282289495
# -- Generation 941 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9302914516120931
#   Std 0.46536447480655896
# -- Generation 942 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9225531491020861
#   Std 0.46140418914256875
# -- Generation 943 --
#   Evaluated 1059 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9311664162050597
#   Std 0.4659113516399177
# -- Generation 944 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9225681115432199
#   Std 0.46170333733907115
# -- Generation 945 --
#   Evaluated 1038 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.93205296700035
#   Std 0.46657337603807525
# -- Generation 946 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9271763009123566
#   Std 0.46434923345172296
# -- Generation 947 --
#   Evaluated 996 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9403513390443122
#   Std 0.47037620208910486
# -- Generation 948 --
#   Evaluated 1074 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9307303445195838
#   Std 0.46563860667749296
# -- Generation 949 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9359965520044109
#   Std 0.4685633750794254
# -- Generation 950 --
#   Evaluated 1067 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9339420013516038
#   Std 0.46731736064675344
# -- Generation 951 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9355350304863017
#   Std 0.46784042959748734
# -- Generation 952 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9281763345247797
#   Std 0.46442998495380344
# -- Generation 953 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9302871616814185
#   Std 0.46539881002376066
# -- Generation 954 --
#   Evaluated 1059 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9141010719810224
#   Std 0.45743337614400176
# -- Generation 955 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9298643699290544
#   Std 0.4656431722764923
# -- Generation 956 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9198011062580252
#   Std 0.4604474443622427
# -- Generation 957 --
#   Evaluated 1012 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9312359687877201
#   Std 0.4661056692695912
# -- Generation 958 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9271002943526133
#   Std 0.46416993798660305
# -- Generation 959 --
#   Evaluated 990 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9456034977798702
#   Std 0.47300227291004043
# -- Generation 960 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9286791701055866
#   Std 0.46457659287652436
# -- Generation 961 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9193478384608816
#   Std 0.45987445179738956
# -- Generation 962 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9301517550410087
#   Std 0.46553161459899056
# -- Generation 963 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.93875530356864
#   Std 0.46966931513916893
# -- Generation 964 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9262852075244166
#   Std 0.46350263296142885
# -- Generation 965 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9328493890082192
#   Std 0.46694880727848087
# -- Generation 966 --
#   Evaluated 1003 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9261518896788328
#   Std 0.46363646315733
# -- Generation 967 --
#   Evaluated 1069 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.932920265423832
#   Std 0.46697058745693226
# -- Generation 968 --
#   Evaluated 1068 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9269324358937872
#   Std 0.4638855369782531
# -- Generation 969 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9347358197911034
#   Std 0.46763681323262885
# -- Generation 970 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9251826953410133
#   Std 0.4627918766163688
# -- Generation 971 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9379418628594962
#   Std 0.46922160848174815
# -- Generation 972 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.931530509149899
#   Std 0.46616177250355234
# -- Generation 973 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9369201269317244
#   Std 0.4686560488275163
# -- Generation 974 --
#   Evaluated 1010 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9343790231179132
#   Std 0.4675905717670974
# -- Generation 975 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9307247346102399
#   Std 0.46567229310427405
# -- Generation 976 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9246843309555574
#   Std 0.46304859573293555
# -- Generation 977 --
#   Evaluated 996 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9334973134158097
#   Std 0.4671132705763184
# -- Generation 978 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9294091907474776
#   Std 0.46488690165561053
# -- Generation 979 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9300031125650221
#   Std 0.4654390822060571
# -- Generation 980 --
#   Evaluated 1067 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9345175844892046
#   Std 0.46745932119046446
# -- Generation 981 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9324806362348695
#   Std 0.46651375253513566
# -- Generation 982 --
#   Evaluated 980 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9378738115201815
#   Std 0.46905081067518173
# -- Generation 983 --
#   Evaluated 1066 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9245319458571248
#   Std 0.4626624711114078
# -- Generation 984 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9222084971622145
#   Std 0.46161011271942753
# -- Generation 985 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9308896304855432
#   Std 0.46599168209741143
# -- Generation 986 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9358304845403455
#   Std 0.4680610732952621
# -- Generation 987 --
#   Evaluated 1066 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9321761960326721
#   Std 0.46614279463243874
# -- Generation 988 --
#   Evaluated 1006 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9359873807372973
#   Std 0.4684494162482207
# -- Generation 989 --
#   Evaluated 971 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9459041992139051
#   Std 0.4734078379901088
# -- Generation 990 --
#   Evaluated 984 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.924687703340084
#   Std 0.46269015999391355
# -- Generation 991 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9260640022705121
#   Std 0.463305428310784
# -- Generation 992 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9271661519245624
#   Std 0.4640160060005077
# -- Generation 993 --
#   Evaluated 1053 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9198719497988687
#   Std 0.4606970958331909
# -- Generation 994 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9271620432585641
#   Std 0.46405043054537737
# -- Generation 995 --
#   Evaluated 957 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9323368309977867
#   Std 0.46671531687243706
# -- Generation 996 --
#   Evaluated 1015 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9300021586299053
#   Std 0.4653292031065832
# -- Generation 997 --
#   Evaluated 1021 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9353983402561915
#   Std 0.4679726009247102
# -- Generation 998 --
#   Evaluated 1023 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9335812807912911
#   Std 0.46726003680815664
# -- Generation 999 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9263490053220252
#   Std 0.4633750352279614
# -- Generation 1000 --
#   Evaluated 1061 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9244528559637989
#   Std 0.46248165716495093
# -- End of (successful) evolution --
#
#
# -- Final Population --

# %%
display(df_hasil.head())
# Out:
#     antecedents  ... kulczynski
# 0  [39, 73, 77]  ...        1.0
# 1      [39, 73]  ...        1.0
# 2      [39, 73]  ...        1.0
# 3      [39, 73]  ...        0.0
# 4      [39, 73]  ...        1.0
#
# [5 rows x 4 columns]

# %%
print('Nilai fitness minimum pada populasi sebelum GA %s' %round(mins[0], 4))
print('Nilai fitness minimum pada populasi setelah GA %s' %round(mins[-1], 4))
        
print("Nilai fitness maksimum pada populasi sebelum GA %s" %round(maxs[0], 4))
print("Nilai fitness maksimum pada populasi setelah GA %s" %round(maxs[-1], 4))
        
print("Rata-rata nilai fitness pada populasi sebelum GA %s" %round(means[0], 4))
print("Rata-rata nilai fitness pada populasi setelah GA %s" %round(means[-1], 4))
        
print("Standar deviasi nilai fitness pada populasi sebelum GA %s" %round(stds[0], 4))
print("Standar deviasi nilai fitness pada populasi setelah GA %s" %round(stds[-1], 4))
# Out:
# Nilai fitness minimum pada populasi sebelum GA 0.0212
# Nilai fitness minimum pada populasi setelah GA 0.0
# Nilai fitness maksimum pada populasi sebelum GA 0.1165
# Nilai fitness maksimum pada populasi setelah GA 1.0
# Rata-rata nilai fitness pada populasi sebelum GA 0.0334
# Rata-rata nilai fitness pada populasi setelah GA 0.9245
# Standar deviasi nilai fitness pada populasi sebelum GA 0.0328
# Standar deviasi nilai fitness pada populasi setelah GA 0.4625

# %%
# hapus aturan asosiasi yang duplikat
df_hasil['new'] = df_hasil.chromosome.apply(tuple)
df_hasil_akhir = df_hasil.sort_values('kulczynski', ascending=False).drop_duplicates('new').drop(['new'], axis=1)
df_hasil_akhir = df_hasil_akhir[df_hasil_akhir["kulczynski"] != 0.00].reset_index(drop=True)

# hapus aturan asosiasi dengan nilai antecedent / consequent yang hilang
# atau dengan item lebih dari satu pada antecedent / consequent
for id, baris in df_hasil_akhir.iterrows():
    if len(baris['antecedents']) == 0 or len(baris['consequents']) == 0:
        df_hasil_akhir.drop(id, inplace=True)

# %%
display(df_hasil_akhir.head())
# Out:
#     antecedents  ... kulczynski
# 0  [39, 73, 77]  ...        1.0
# 1      [39, 73]  ...        1.0
# 2      [39, 77]  ...        1.0
# 3      [39, 73]  ...        1.0
# 4      [39, 73]  ...        1.0
#
# [5 rows x 4 columns]

# %%
# Periksa aturan asosiasi apakah anteseden mengandung semua restoran
# yang ada pada set data
for i in range(100):
    if [i+1] in df_hasil_akhir['antecedents'].tolist() == False:
        print(i+1, " tidak ada")

# %%
def lookup_item(k):
    return list(restaurant_replace_map_comp.keys())[list(restaurant_replace_map_comp.values()).index(k)]

for baris in df_hasil_akhir.itertuples():
    print("Aturan Asosiasi #{0}".format(baris.Index + 1))
    (premise, conclusion) = (baris.antecedents, baris.consequents)
    premise_names = ", ".join(lookup_item(elemen) for elemen in premise)
    conclusion_names = ", ".join(lookup_item(elemen) for elemen in conclusion)
    print("Aturan Asosiasi: Jika seseorang merekomendasi {0}, maka ia juga akan merekomendasi {1}".format(premise_names, conclusion_names))
    print(" - Kulczynski: {0:.2f}".format(baris.kulczynski))
    print("\n")
# Out:
# Aturan Asosiasi #1
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Royal Spicy Restaurant, Shah Ghouse Spl Shawarma, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #2
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Royal Spicy Restaurant, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #3
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Shah Ghouse Spl Shawarma, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #4
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Royal Spicy Restaurant, maka ia juga akan merekomendasi Kritunga Restaurant, eat.fit
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #5
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Royal Spicy Restaurant, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand, eat.fit
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #6
# Aturan Asosiasi: Jika seseorang merekomendasi Royal Spicy Restaurant, Shah Ghouse Spl Shawarma, eat.fit, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #7
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Royal Spicy Restaurant, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand, Shah Ghouse Spl Shawarma
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #8
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Royal Spicy Restaurant, Shah Ghouse Spl Shawarma, maka ia juga akan merekomendasi Kritunga Restaurant, eat.fit
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #9
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Shah Ghouse Spl Shawarma, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand, eat.fit
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #10
# Aturan Asosiasi: Jika seseorang merekomendasi Pakwaan Grand, Royal Spicy Restaurant, maka ia juga akan merekomendasi Gal Punjab Di, Kritunga Restaurant
#  - Kulczynski: 0.75
#
#
# Aturan Asosiasi #11
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, Royal Spicy Restaurant, maka ia juga akan merekomendasi Kritunga Restaurant, Shah Ghouse Spl Shawarma
#  - Kulczynski: 0.75
#
#
# Aturan Asosiasi #12
# Aturan Asosiasi: Jika seseorang merekomendasi Gal Punjab Di, maka ia juga akan merekomendasi Kritunga Restaurant, Pakwaan Grand
#  - Kulczynski: 0.51

# %% [markdown]
# ## 6. Rekomendasi Restoran

# %%
def lookup_id_restoran(nama_restoran):
    return int(restaurant_replace_map_comp.get(nama_restoran))

def rekomendasi_restoran(id_restoran_prefensi):
    list_temp = []

    for indeks, baris in df_hasil_akhir.iterrows():
        if id_restoran_prefensi in baris['antecedents']:
            list_temp.append(baris)
    df_extract = pd.DataFrame(list_temp,
                           columns = ['antecedents',
                                      'consequents',
                                      'chromosome',
                                      'kulczynski']).reset_index(drop=True)
    
    # sortir baris pada df_extract berdasarkan kolom kulczynski
    df_extract = df_extract.sort_values('kulczynski', ascending=False)
    
    # pilih aturan asosiasi top 3
    # df_extract = df_extract.head(3)

    # kombinasikan setiap item pada consequent
    list_top_restaurant = []
    for i in df_extract['consequents']:
        list_top_restaurant = list_top_restaurant + i

    list_rekomendasi = []
    for i in list_top_restaurant:
        list_rekomendasi = list_rekomendasi + [lookup_item(i)]

    return list(dict.fromkeys(list_rekomendasi))

# %%
# print('Masukkan restoran preferensi:')
x = input('')
print('Rekomendasi adalah', rekomendasi_restoran(lookup_id_restoran(x)))
# Out:
# Pakwaan Grand
# Rekomendasi adalah ['Gal Punjab Di', 'Kritunga Restaurant']
