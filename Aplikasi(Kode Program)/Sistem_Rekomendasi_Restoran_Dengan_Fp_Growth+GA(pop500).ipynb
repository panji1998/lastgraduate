# %% [markdown]
# # Tugas Akhir TA-11 Sistem Informasi T.A. 2019/2020
# - Association Analysis using Frequent Pattern Growth-Genetic Algorithm for Restaurant Recommendation System
# - (12S16013) Panji Jonatan Situmorang dan (12S16051) Hesti Rugun Juli Arta Siagian
# - Notebook ini ditujukan untuk mendemonstrasikan sistem yang dirancang.

# %% [markdown]
# ## 1. Muat Pustaka Python

# %%
import ast
import math
import numpy as np
import pandas as pd
import random
import re
import time

# Gunakan modul fpgrowth dalam mlxtend library untuk melakukan
# FP-Growth
try:
    import mlxtend
    from mlxtend.preprocessing import TransactionEncoder
    from mlxtend.frequent_patterns import fpgrowth
    from mlxtend.frequent_patterns import association_rules
except:
    # %pip install mlxtend --upgrade
    import mlxtend
    from mlxtend.preprocessing import TransactionEncoder
    from mlxtend.frequent_patterns import fpgrowth
    from mlxtend.frequent_patterns import association_rules

# Gunakan deap library untuk melakukan
# Genetic Algorithm
try:
    # Gunakan deap library untuk melakukan
    # Genetic Algorithm
    from deap import base
    from deap import creator
    from deap import tools
except:
    # %pip install deap --upgrade
    from deap import base
    from deap import creator
    from deap import tools

# %% [markdown]
# ## 2. Muat Data

# %% [markdown]
# Pada _cell_ berikut ini dilakukan pembacaan set data **"Restaurant reviews"** dan **"Restaurant names and Metadata.csv"**. Keduanya digabungkan dan disimpan dalam struktur data _DataFrame_ bernama <code>df_tr_restoran</code>.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Menyimpan set data review restoran dalam DataFrame df_review_restoran
df_review_restoran = pd.read_csv("/content/drive/MyDrive/Restaurant reviews.csv",
                                 usecols = ["Restaurant", "Reviewer", "Rating"])

# Menyimpan set data metadata restoran dalam DataFrame df_md_restoran
df_md_restoran = pd.read_csv("/content/drive/MyDrive/Restaurant names and Metadata.csv",
                             usecols = ["Name", "Cuisines"])

# Menyimpan gabungan df_review_restoran dan df_md_restoran dalam DataFrame df_tr_restoran
df_tr_restoran = df_md_restoran.merge(df_review_restoran,
                                      left_on = "Name",
                                      right_on = "Restaurant",
                                      how = "inner").drop(["Name"], axis = 1)

# Ganti nama kolom "Restaurant" menjadi "Preferred Restaurant"
df_tr_restoran = df_tr_restoran.rename(columns={"Restaurant": "Preferred Restaurant"})

# %% [markdown]
# ## 3. Prapemrosesan

# %%
# Hapus baris data yang memiliki setidaknya satu nilai atribut hilang (NaN / None)
df_tr_restoran = df_tr_restoran.dropna(axis = 0, how ='any')
df_tr_restoran = df_tr_restoran.reset_index(drop=True)

# %%
# Pastikan tipe data Rating adalah numerik 
df_tr_restoran['Rating'] = pd.to_numeric(df_tr_restoran['Rating'], errors='coerce')

# Pilih restoran dengan rating baik (rating >= 3)
df_tr_restoran = df_tr_restoran[df_tr_restoran['Rating'] >= 3]
df_tr_restoran = df_tr_restoran.drop(['Rating'], axis=1)
df_tr_restoran = df_tr_restoran.reset_index(drop=True)

# %%
# Pengelompokkan restoran berdasarkan reviewer
df_tr_restoran = df_tr_restoran.groupby(by = ["Reviewer"])["Preferred Restaurant"].apply(list).reset_index()
display(df_tr_restoran.head())
# Out:
#                       Reviewer               Preferred Restaurant
# 0                    #FOODPORN  [Zega - Sheraton Hyderabad Hotel]
# 1          #chloesviews // CAH                          [eat.fit]
# 2                         $ign                            [SKYHY]
# 3  @FuloriBinaChutneyKaiseBani                 [Chinese Pavilion]
# 4            @Vignesh #FoodMad                      [Owm Nom Nom]

# %%
# Pengkodean Label pada nama restoran  
# Simpan set pemetaan dalam restaurant_replace_map_comp
restaurant_labels = np.unique(np.concatenate([np.unique(row) for row in df_tr_restoran['Preferred Restaurant']])).tolist()
restaurant_replace_map_comp = {v: k for k, v in zip(list(range(1,len(restaurant_labels)+1)), restaurant_labels)}

# Ganti setiap nama restoran dengan indeks yang sesuai 
for i, row in df_tr_restoran.iterrows():
    res = [restaurant_replace_map_comp.get(ele, ele) for ele in row['Preferred Restaurant']]
    df_tr_restoran.at[i, 'Preferred Restaurant'] = np.array(res)

# %%
display(df_tr_restoran.tail())
# Out:
#                  Reviewer Preferred Restaurant
# 5626  విజయ్ కుమార్ తెజవత్                 [44]
# 5627       ಅಭಿಷೇಕ್ ಉಪಾಧ್ಯ                 [80]
# 5628        ✌️✌️Reddy 🥂🍽️                 [47]
# 5629              ✔️ Sonu                 [76]
# 5630                  🍛🍲🥗             [67, 34]

# %%
# Simpan hasil prapemrosesan dalam Numpy Array np_transaksi_restoran
np_transaksi_restoran = df_tr_restoran['Preferred Restaurant'].to_numpy()

# %% [markdown]
# ## 4. Penerapan FP-Growth

# %%
dataset = df_tr_restoran['Preferred Restaurant'].tolist()

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
display(df.tail())
# Out:
#         1      2      3      4      5    ...    96     97     98     99     100
# 5626  False  False  False  False  False  ...  False  False  False  False  False
# 5627  False  False  False  False  False  ...  False  False  False  False  False
# 5628  False  False  False  False  False  ...  False  False  False  False  False
# 5629  False  False  False  False  False  ...  False  False  False  False  False
# 5630  False  False  False  False  False  ...  False  False  False  False  False
#
# [5 rows x 100 columns]

# %%
# minimal 2 kali dari seluruh transaksi
df_frequent_itemsets = fpgrowth(df, min_support=(2/len(df)), max_len=2, use_colnames=True)

# %%
df_rules = association_rules(df_frequent_itemsets, metric="confidence", min_threshold=(2/len(df)))
# df_rules = association_rules(df_frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
df_rules.tail()
# Out:
#      antecedents consequents  ...  leverage  conviction
# 1709        (61)        (67)  ...  0.000234    1.018287
# 1710        (26)        (67)  ...  0.000216    1.014639
# 1711        (67)        (26)  ...  0.000216    1.024301
# 1712        (67)        (95)  ...  0.000245    1.027626
# 1713        (95)        (67)  ...  0.000245    1.021250
#
# [5 rows x 9 columns]

# %%
# Fungsi _Encoding_ dan _Decoding_ pada Aturan Asosiasi
# Michigan Encoding
def michigan_encoding(df_association_rules, list_items):
    list_encoded_association_rules = []

    for tuple_rule in df_association_rules.itertuples():
        list_encoded_rule = []
        
        for item in list_items:
            if item in tuple_rule.antecedents:
                list_encoded_rule.append('01')
            elif item in tuple_rule.consequents:
                list_encoded_rule.append('10')
            else:
                list_encoded_rule.append('00')
        list_encoded_association_rules.append(list_encoded_rule)
    return list_encoded_association_rules

# Michigan Decoding
def michigan_decoding(list_encoded_association_rules, list_items):
    list_rules = []
    
    for encoded_rule in list_encoded_association_rules:
        antecedent = []
        consequent = []

        for idx, ele in enumerate(encoded_rule):
            if ele == '01':
                antecedent.append(list_items[idx])
            elif ele == '10':
                consequent.append(list_items[idx])
        list_rules.append([antecedent, consequent, encoded_rule])
    
    return pd.DataFrame(list_rules, columns=['antecedents', 'consequents', 'chromosome'])

# %% [markdown]
# Jalankan _encoding_.

# %%
list_encoded_association_rules = michigan_encoding(df_rules, [*restaurant_replace_map_comp.values()])

# %%
# cuplikan aturan asosiasi yang telah di-encode 
for index, rule in enumerate(list_encoded_association_rules):
    print(index, ":", str(rule))
    if index == 1:
        break
# Out:
# 0 : ['00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '10', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '01']
# 1 : ['00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '01', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '00', '10']

# %% [markdown]
# ## 5. Penerapan Genetic Algorithm

# %% [markdown]
# **Creator**
#
# Karena struktur aktual individu yang diperlukan dalam _genetic algorithm_ sangat bergantung pada kasus yang akan diselesaikan, maka DEAP _library_ tidak menyediakan struktur eksplisit apa pun. Namun, DEAP _library_ menyediakan _method_ untuk membuat wadah bagi atribut, terkait dengan _fitness_. _Method_ ini disebut <code>deap.creator</code>.
#
# <code>creator</code> adalah "pabrik kelas" yang dapat kita gunakan untuk membuat kelas baru pada saat program dijalankan. Pemanggilannya dilengkapi dengan beberapa argumen. Argumen pertama yaitu nama yang diinginkan dari kelas baru yang akan dibuat, argumen kedua adalah kelas dasar yang akan diwarisi, dan argumen berikutnya adalah atribut kelas baru yang dibuat.
#
# Pada _cell_ berikut ini, kita mendefinisikan sebuah kelas bernama **"FitnessMax"**. Kelas ini akan mewarisi kelas **"Fitness"** dari modul <code>deap.base</code>. Kelas ini juga akan memiliki atribut tambahan yang disebut **"weights"**. Perhatikan bahwa nilai **"weights"** disajikan dengan bentuk _tuple_ (1.0,). Dengan cara ini, kita secara eksplisit menyatakan bahwa kasus optimasi yang dikerjakan adalah memaksimalkan _fitness_ objektif tunggal.

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))

# %% [markdown]
# Selanjutnya, kita buat kelas bernama **"Individual"**, yang akan mewarisi kelas **"list"** dan mengandung kelas **"FitnessMax"** yang telah kita definisikan sebelumnya dalam atribut **"fitness"**.

# %%
creator.create("Individual", list, fitness=creator.FitnessMax)

# %% [markdown]
# **Toolbox**

# %%
toolbox = base.Toolbox()

# %% [markdown]
# **Evaluation Function**
#
# - $ \mathrm{support}(A->C) = \mathrm{support}(A \cup C)$, range: [0, 1]
#
#
#
# - $ \mathrm{confidence}(A->C) = \frac{\mathrm{support}(A \cup C)}{\mathrm{support}(A)}$, range: [0, 1]
#
#
#
# - $ \mathrm{lift}(A->C) = \frac{\mathrm{confidence}(A->C)}{\mathrm{support}(C)}$, range: [0, inf]
#
#
#
# - $ \mathrm{kulczynski}(A->C) = \frac{1}{2} (\frac{\mathrm{support}(A \cup C)}{\mathrm{support}(A)} + \frac{\mathrm{support}(A \cup C)}{\mathrm{support}(C)}) $, range: [0, 1]

# %%
def safe_div(x,y):
    if y==0: return 0
    return x/y

def kulczynski(encoded_rule, np_data_transaksi, list_items):
    antecedent = []
    consequent = []

    for idx, ele in enumerate(encoded_rule):
        if ele == '01':
            antecedent.append(list_items[idx])
        elif ele == '10':
            consequent.append(list_items[idx])
    decoded_rule = antecedent + consequent

    support_rule = [bool(set(decoded_rule) and set(decoded_rule).issubset(set(sublist))) \
                    for sublist in np_data_transaksi].count(True) / len(np_data_transaksi)
    support_antecedent = [bool(set(antecedent) and set(antecedent).issubset(set(sublist))) \
                    for sublist in np_data_transaksi].count(True) / len(np_data_transaksi)
    support_consequent = [bool(set(consequent) and set(consequent).issubset(set(sublist))) \
                    for sublist in np_data_transaksi].count(True) / len(np_data_transaksi)
    kulczynski_rule = (1/2) * (safe_div(support_rule, support_antecedent) + safe_div(support_rule, support_consequent))
    
    return kulczynski_rule

def evalOneMax(individual):
    return kulczynski(individual, np_transaksi_restoran, [*restaurant_replace_map_comp.values()]),

# %% [markdown]
# **The Genetic Operators**

# %%
#----------
# Registrasi Operator Genetik
#----------
# Registrasi tujuan / fungsi fitness 'evalOneMax'
toolbox.register("evaluate", evalOneMax)

# Registrasi operator crossover dengan
# teknik one point crossover
toolbox.register("mate", tools.cxOnePoint)

# Registrasi operator mutation dengan teknik DNA shuffling
# dan probabilitas setiap DNA dipindahkan
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.05)

# Registrasi operator dengan teknik tournament selection 
# untuk memilih individu-individu di generasi selanjutnya
# di mana setiap individu dari generasi sebelumnya digantikan
# dengan 2 individu dari generasi saat ini
toolbox.register("select", tools.selTournament, tournsize=2)

#----------

# %% [markdown]
# **Creating the Population**

# %%
mins=[]
maxs=[]
means=[]
stds=[]

def main(): 
    pop = []
    # Konversi struktur data setiap kromosom dari 'list'
    # menjadi 'deap.creator.Individual' supaya dapat
    # digunakan di algoritma GA dalam DEAP library
    for rule in list_encoded_association_rules:
        pop.append(creator.Individual(rule))
    
    # CXPB adalah probabilitas dua individu
    # disilangkan
    #
    # MUTPB adalah probabilitas sebuah individu
    # mengalami mutasi
    CXPB, MUTPB = 0.5, 0.2

    print('Start of evolution')

    # Hitung nilai fitness seluruh individu dalam populasi
    # dengan menggunakan 'evalOneMax' yang sudah disimpan
    # dalam 'toolbox.evaluate' di cell 
    # 'Registrasi Operator Genetik'
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit

    print('  Evaluated %i individuals' % len(pop))

    # Ekstraksi nilai fitness setiap individu 'ind'
    # dalam populasi 'pop' dan simpan dalam list 'fits'
    fits = [ind.fitness.values[0] for ind in pop]
    
    length = len(pop)
    mean = sum(fits) / length
    sum2 = sum(x*x for x in fits)
    std = abs(sum2 / length - mean*2)*0.5
        
    mins.append(min(fits))
    maxs.append(max(fits))
    means.append(mean)
    stds.append(std)
    
    print('  Min %s' % min(fits))
    print('  Max %s' % max(fits))
    print('  Avg %s' % mean)
    print('  Std %s' % std)        
    
    # Variabel 'g' untuk pemantauan total generasi
    # di mana satu generasi sama dengan satu iterasi
    g = 0

    # Lakukan evolusi selama generasi 'g'
    # lebih kecil dari 500
    while g < 500:
        # Sebuah generasi baru
        g = g + 1
        print('-- Generation %i --' % g)

        # Pilih individu-individu untuk generasi selanjutnya
        offspring = toolbox.select(pop, len(pop))
        # Kloning individu-individu yang terpilih
        offspring = list(map(toolbox.clone, offspring))

        # Terapkan penyilangan dan mutation pada  
        # individu yang merupakan anakan 'offspring'
        for child1, child2 in zip(offspring[::2], offspring[1::2]):

            # Silangkan dua individu dengan menggunakan 
            # CXPB
            if random.random() < CXPB:
                toolbox.mate(child1, child2)

                # Hapus nilai fitness value hasil
                # persilangan karena invalid
                del child1.fitness.values
                del child2.fitness.values

        for mutant in offspring:

            # Mutasi sebuah individu dengan menggunakan
            # MUTPB
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Kalkulasi ulang nilai fitness individu-individu
        # 'offspring'
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        print('  Evaluated %i individuals' % len(invalid_ind))

        # Gantikan populasi seutuhnya dengan menggunakan 
        # offspring
        pop[:] = offspring

        # Kumpulkan semua fitness dalam sebuah list 
        # dan untuk ditampilkan statistiknya seperti
        # min, max, rata-rata, dan standar deviasi
        fits = [ind.fitness.values[0] for ind in pop]

        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean*2)*0.5
        
        mins.append(min(fits))
        maxs.append(max(fits))
        means.append(mean)
        stds.append(std)
        
        print('  Min %s' % min(fits))
        print('  Max %s' % max(fits))
        print('  Avg %s' % mean)
        print('  Std %s' % std)

    print('-- End of (successful) evolution --')
    print('\n')
    
    # Tampilkan populasi akhir
    print('-- Final Population --')
    df_fits = pd.DataFrame(fits, columns =['kulczynski']) 
    df_pop = michigan_decoding(pop, [*restaurant_replace_map_comp.values()])
    df_pop = pd.concat([df_pop, df_fits], axis=1)
    print('\n')
    
    return df_pop

if __name__ == '__main__':
    df_hasil = main()
# Out:
# Start of evolution
#   Evaluated 1714 individuals
#   Min 0.02119309262166405
#   Max 0.11652188439692615
#   Avg 0.03343791297628511
#   Std 0.03280754231621501
# -- Generation 1 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 0.5083333333333333
#   Avg 0.09803840938928657
#   Std 0.07973816135679147
# -- Generation 2 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 0.5113636363636364
#   Avg 0.1792607123717321
#   Std 0.13967817015477518
# -- Generation 3 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 0.5113636363636364
#   Avg 0.2674143137724577
#   Std 0.2044723337377257
# -- Generation 4 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 0.5113636363636364
#   Avg 0.34918570964944284
#   Std 0.26417243247006217
# -- Generation 5 --
#   Evaluated 1001 individuals
#   Min 0.0
#   Max 0.5083333333333333
#   Avg 0.40187461994248397
#   Std 0.3024232321391541
# -- Generation 6 --
#   Evaluated 1021 individuals
#   Min 0.0
#   Max 0.5083333333333333
#   Avg 0.42056857131790304
#   Std 0.3159304408803122
# -- Generation 7 --
#   Evaluated 986 individuals
#   Min 0.0
#   Max 0.5083333333333333
#   Avg 0.4254303898132461
#   Std 0.31942804197539343
# -- Generation 8 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 0.5083333333333333
#   Avg 0.4224221943802106
#   Std 0.31711568979393323
# -- Generation 9 --
#   Evaluated 993 individuals
#   Min 0.0
#   Max 0.5079365079365079
#   Avg 0.42476859470896783
#   Std 0.3188228506536799
# -- Generation 10 --
#   Evaluated 1007 individuals
#   Min 0.0
#   Max 0.5079365079365079
#   Avg 0.42486537110145844
#   Std 0.31883484511450305
# -- Generation 11 --
#   Evaluated 995 individuals
#   Min 0.0
#   Max 0.5079365079365079
#   Avg 0.4233744201638559
#   Std 0.31776661921570065
# -- Generation 12 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 0.5079365079365079
#   Avg 0.42249364731316086
#   Std 0.3171067902317405
# -- Generation 13 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 0.6666666666666667
#   Avg 0.4224849053769747
#   Std 0.31690501611629
# -- Generation 14 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 0.6666666666666667
#   Avg 0.4140918886999522
#   Std 0.31046442225038895
# -- Generation 15 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.4090275728831262
#   Std 0.3065086504901736
# -- Generation 16 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.41354019641368456
#   Std 0.30986145887657646
# -- Generation 17 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.40620738893798897
#   Std 0.3038591156295848
# -- Generation 18 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.3812049236885264
#   Std 0.2851213376631383
# -- Generation 19 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.38447487998769486
#   Std 0.28737786354815587
# -- Generation 20 --
#   Evaluated 1075 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.3811076362002636
#   Std 0.28448852248801754
# -- Generation 21 --
#   Evaluated 968 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.39882885087887904
#   Std 0.29684540127752823
# -- Generation 22 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.40416787235971274
#   Std 0.2997650077889858
# -- Generation 23 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.41937395169031766
#   Std 0.30966815155419253
# -- Generation 24 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.44736856875485653
#   Std 0.32946962304940036
# -- Generation 25 --
#   Evaluated 1075 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.46774274547958666
#   Std 0.3421856590097989
# -- Generation 26 --
#   Evaluated 1070 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.4841315423267875
#   Std 0.3499986583013388
# -- Generation 27 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.5029724751343273
#   Std 0.35671794238982024
# -- Generation 28 --
#   Evaluated 992 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.5328080482457971
#   Std 0.36737025758351105
# -- Generation 29 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.5642291011023346
#   Std 0.3774862135562695
# -- Generation 30 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.5975539949475187
#   Std 0.3881842113412164
# -- Generation 31 --
#   Evaluated 984 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.6241818111489471
#   Std 0.3964626373076764
# -- Generation 32 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.6487972625837274
#   Std 0.4083748827599583
# -- Generation 33 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.666260986500193
#   Std 0.4175627325792873
# -- Generation 34 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 0.75
#   Avg 0.6636543182507504
#   Std 0.41571116086813575
# -- Generation 35 --
#   Evaluated 1053 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6712338814679364
#   Std 0.4204857987331218
# -- Generation 36 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6930187206508077
#   Std 0.43326803287406257
# -- Generation 37 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6915734874174704
#   Std 0.43212967049189316
# -- Generation 38 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6925556265550431
#   Std 0.4321149562907601
# -- Generation 39 --
#   Evaluated 1102 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6868694735332229
#   Std 0.42823893307700367
# -- Generation 40 --
#   Evaluated 998 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6986409170521545
#   Std 0.43473196145106285
# -- Generation 41 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6943810311425398
#   Std 0.42963250055669855
# -- Generation 42 --
#   Evaluated 1075 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.6995556707597255
#   Std 0.43198996048251004
# -- Generation 43 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7038912546305528
#   Std 0.43051170627255614
# -- Generation 44 --
#   Evaluated 1074 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.705959461607799
#   Std 0.4268317738922762
# -- Generation 45 --
#   Evaluated 1010 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7139939604131553
#   Std 0.4257054717429091
# -- Generation 46 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7266157539709239
#   Std 0.4245338104486625
# -- Generation 47 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7360883461107665
#   Std 0.4189780546455312
# -- Generation 48 --
#   Evaluated 978 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7483334027893539
#   Std 0.41718477968960205
# -- Generation 49 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7745835982951891
#   Std 0.42271062525901476
# -- Generation 50 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7872645312284556
#   Std 0.4215637939030742
# -- Generation 51 --
#   Evaluated 984 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8162934305923412
#   Std 0.42920849435796804
# -- Generation 52 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.7978146049032863
#   Std 0.4157560202303007
# -- Generation 53 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8150385556148694
#   Std 0.4256201869037907
# -- Generation 54 --
#   Evaluated 1019 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.817813030179194
#   Std 0.4270029574278235
# -- Generation 55 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8489833825184847
#   Std 0.4421138733659057
# -- Generation 56 --
#   Evaluated 1003 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8585940570856453
#   Std 0.44506667095738295
# -- Generation 57 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8398826373325585
#   Std 0.4345716124632915
# -- Generation 58 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8471860472115718
#   Std 0.43901638630871376
# -- Generation 59 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8564067197928044
#   Std 0.4430705198373179
# -- Generation 60 --
#   Evaluated 1007 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8624294828459049
#   Std 0.4457492760512883
# -- Generation 61 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8554472194045127
#   Std 0.44293268756978493
# -- Generation 62 --
#   Evaluated 999 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8564953019433271
#   Std 0.44153794081678
# -- Generation 63 --
#   Evaluated 1069 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8579205201895779
#   Std 0.44577811928010014
# -- Generation 64 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8765471135621364
#   Std 0.4514225446149082
# -- Generation 65 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8790166673869504
#   Std 0.45179132092655744
# -- Generation 66 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8734185700188705
#   Std 0.45016363980760427
# -- Generation 67 --
#   Evaluated 1079 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8725999560231671
#   Std 0.44892938301076873
# -- Generation 68 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8842963089012773
#   Std 0.45560704310308736
# -- Generation 69 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8846168355734182
#   Std 0.4532650753873071
# -- Generation 70 --
#   Evaluated 961 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8827271237593091
#   Std 0.45317711596775817
# -- Generation 71 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8833817274586908
#   Std 0.4531169823227332
# -- Generation 72 --
#   Evaluated 1072 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8627745530239019
#   Std 0.4462771659066528
# -- Generation 73 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.869183285755078
#   Std 0.44655097986445735
# -- Generation 74 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8836841119610463
#   Std 0.4527941048830275
# -- Generation 75 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.88476017222006
#   Std 0.4529356391281243
# -- Generation 76 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8736522018707262
#   Std 0.44885375101336483
# -- Generation 77 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8855905534787107
#   Std 0.4543307258436438
# -- Generation 78 --
#   Evaluated 994 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.877201899711313
#   Std 0.4495575263832383
# -- Generation 79 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8874606544506385
#   Std 0.45434513364820667
# -- Generation 80 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8963830455796122
#   Std 0.4569969339191873
# -- Generation 81 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8923614712534386
#   Std 0.45677270621238375
# -- Generation 82 --
#   Evaluated 1006 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8840770722589557
#   Std 0.45094872039784234
# -- Generation 83 --
#   Evaluated 1088 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8953689748188477
#   Std 0.4559793763915637
# -- Generation 84 --
#   Evaluated 1015 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8931045349121963
#   Std 0.4550613962464351
# -- Generation 85 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8835577020038312
#   Std 0.4500919637468504
# -- Generation 86 --
#   Evaluated 1075 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8906873496405774
#   Std 0.45290931849530813
# -- Generation 87 --
#   Evaluated 1020 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8959475884869694
#   Std 0.4562778184626064
# -- Generation 88 --
#   Evaluated 998 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8934181738623098
#   Std 0.4535729184392421
# -- Generation 89 --
#   Evaluated 1073 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9048233862022262
#   Std 0.45806778337062637
# -- Generation 90 --
#   Evaluated 1073 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9024653993258132
#   Std 0.45579494173910023
# -- Generation 91 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9169724515539492
#   Std 0.4625060726075871
# -- Generation 92 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9119104920264487
#   Std 0.45866702785003133
# -- Generation 93 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9039879910540641
#   Std 0.4554760002559259
# -- Generation 94 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.900158372588847
#   Std 0.45269528084512894
# -- Generation 95 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9032307467911315
#   Std 0.45476016546739245
# -- Generation 96 --
#   Evaluated 1019 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.914925288474005
#   Std 0.4592812014933303
# -- Generation 97 --
#   Evaluated 1028 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8918368339167638
#   Std 0.4482519375094538
# -- Generation 98 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8931143037728504
#   Std 0.44979760268445546
# -- Generation 99 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9067746823544665
#   Std 0.4554255322172072
# -- Generation 100 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9173416634253856
#   Std 0.4601566123932177
# -- Generation 101 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9213251977181383
#   Std 0.4613508136853185
# -- Generation 102 --
#   Evaluated 1071 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9161626474782835
#   Std 0.45904752877087035
# -- Generation 103 --
#   Evaluated 1072 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9145310676779462
#   Std 0.45755723772972573
# -- Generation 104 --
#   Evaluated 1015 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9078908984830805
#   Std 0.45434199970828465
# -- Generation 105 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9270055425904317
#   Std 0.463881066766336
# -- Generation 106 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9216051633605601
#   Std 0.46105326310895567
# -- Generation 107 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9069699695319589
#   Std 0.45443296898746866
# -- Generation 108 --
#   Evaluated 1054 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9096602327239725
#   Std 0.45570064184678283
# -- Generation 109 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9095828471411902
#   Std 0.45530187974037345
# -- Generation 110 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9082555425904317
#   Std 0.45418246791131855
# -- Generation 111 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9062135355892649
#   Std 0.4532708576429405
# -- Generation 112 --
#   Evaluated 995 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9140209710877738
#   Std 0.4572611642996311
# -- Generation 113 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9081943634124204
#   Std 0.45449369264170686
# -- Generation 114 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9154831939582523
#   Std 0.4580651931612123
# -- Generation 115 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9181779139115778
#   Std 0.45932596155750743
# -- Generation 116 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9125660410994425
#   Std 0.4567533859850163
# -- Generation 117 --
#   Evaluated 1070 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9090618112277972
#   Std 0.45489097760184816
# -- Generation 118 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9238700084273304
#   Std 0.46219022962562295
# -- Generation 119 --
#   Evaluated 1002 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9151995263733704
#   Std 0.45817858249058413
# -- Generation 120 --
#   Evaluated 1065 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9106739433424089
#   Std 0.4558975724550092
# -- Generation 121 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9197904511863086
#   Std 0.46055154278220733
# -- Generation 122 --
#   Evaluated 1020 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9174526772980682
#   Std 0.45898156138806057
# -- Generation 123 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9060676779463244
#   Std 0.4530338389731622
# -- Generation 124 --
#   Evaluated 1006 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.926856443666537
#   Std 0.46367890058901273
# -- Generation 125 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.910812102943083
#   Std 0.4557661234594911
# -- Generation 126 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9132228056527939
#   Std 0.45692132218152604
# -- Generation 127 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9158401400233372
#   Std 0.45819355309218207
# -- Generation 128 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9146850285232725
#   Std 0.45794413750751806
# -- Generation 129 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9098761830675481
#   Std 0.4555305819359809
# -- Generation 130 --
#   Evaluated 1077 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.904171528588098
#   Std 0.4525506855309218
# -- Generation 131 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170106476079346
#   Std 0.45893376923497664
# -- Generation 132 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9047711655646312
#   Std 0.4529507248764712
# -- Generation 133 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9190571113704135
#   Std 0.4598384750403358
# -- Generation 134 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9168692467263062
#   Std 0.45868984610217955
# -- Generation 135 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.914969045766887
#   Std 0.45761213425295666
# -- Generation 136 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9142478607545702
#   Std 0.45767085433413285
# -- Generation 137 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9122747309736807
#   Std 0.45657035222820047
# -- Generation 138 --
#   Evaluated 997 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9205075845974329
#   Std 0.4603084889148191
# -- Generation 139 --
#   Evaluated 1059 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9257742609879425
#   Std 0.4634522752610582
# -- Generation 140 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9121329249319332
#   Std 0.45651766734463467
# -- Generation 141 --
#   Evaluated 1053 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9157063816825889
#   Std 0.45829072194872317
# -- Generation 142 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9154228251004797
#   Std 0.45862295247831936
# -- Generation 143 --
#   Evaluated 977 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9100179891092958
#   Std 0.45539182866318745
# -- Generation 144 --
#   Evaluated 1072 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8984142032931414
#   Std 0.44940308378621224
# -- Generation 145 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9041103494100869
#   Std 0.45264312379689964
# -- Generation 146 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9122013969920911
#   Std 0.4563559239080033
# -- Generation 147 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9147535005834304
#   Std 0.4577550457628353
# -- Generation 148 --
#   Evaluated 998 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9219734539089848
#   Std 0.46148808981184364
# -- Generation 149 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9104515104369245
#   Std 0.4554809779574886
# -- Generation 150 --
#   Evaluated 998 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.918031651108518
#   Std 0.4590887429806009
# -- Generation 151 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9111844450927006
#   Std 0.4559750593278213
# -- Generation 152 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9199399552703229
#   Std 0.4605351224022484
# -- Generation 153 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9278081092853374
#   Std 0.4642139770535156
# -- Generation 154 --
#   Evaluated 1055 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9209451575262544
#   Std 0.4605819719953326
# -- Generation 155 --
#   Evaluated 1060 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9111884411925071
#   Std 0.4560874498249548
# -- Generation 156 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9187613444833398
#   Std 0.4596176768433885
# -- Generation 157 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9136522753792299
#   Std 0.4570449241540257
# -- Generation 158 --
#   Evaluated 1015 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9060713243873978
#   Std 0.45321797285224613
# -- Generation 159 --
#   Evaluated 1007 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9103777712952158
#   Std 0.45567657435093345
# -- Generation 160 --
#   Evaluated 985 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9173064144950085
#   Std 0.45896312927556476
# -- Generation 161 --
#   Evaluated 1067 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9280994749124855
#   Std 0.46425026892502924
# -- Generation 162 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9245296091015169
#   Std 0.4626613208321179
# -- Generation 163 --
#   Evaluated 1043 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9130068553092182
#   Std 0.4570640337842766
# -- Generation 164 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9065174056787243
#   Std 0.45383297510426124
# -- Generation 165 --
#   Evaluated 991 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9162890574354985
#   Std 0.4585820647882543
# -- Generation 166 --
#   Evaluated 990 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9136599734214961
#   Std 0.45712258814370926
# -- Generation 167 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9057260724643857
#   Std 0.4536423870048783
# -- Generation 168 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9159430506936341
#   Std 0.4592248929589474
# -- Generation 169 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9152603558926488
#   Std 0.4578671852209743
# -- Generation 170 --
#   Evaluated 993 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9113339491767145
#   Std 0.4563688635686322
# -- Generation 171 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.908113736548684
#   Std 0.45412978302775253
# -- Generation 172 --
#   Evaluated 976 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9203694249967588
#   Std 0.4604399379103372
# -- Generation 173 --
#   Evaluated 982 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9186231848826655
#   Std 0.45974912583890637
# -- Generation 174 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.918481784001037
#   Std 0.4596966408624686
# -- Generation 175 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9143977699987035
#   Std 0.45787342032571277
# -- Generation 176 --
#   Evaluated 998 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9172371321146116
#   Std 0.4589805397655653
# -- Generation 177 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9178861986256969
#   Std 0.45907071068236166
# -- Generation 178 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9138787598859068
#   Std 0.4574270659733476
# -- Generation 179 --
#   Evaluated 977 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9229871645274212
#   Std 0.4614935822637106
# -- Generation 180 --
#   Evaluated 1043 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9161395533514844
#   Std 0.45859848516821344
# -- Generation 181 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9174636166212887
#   Std 0.45931517656090187
# -- Generation 182 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.922116070270971
#   Std 0.4613497363533067
# -- Generation 183 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9245308245818747
#   Std 0.4626619205535027
# -- Generation 184 --
#   Evaluated 986 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9178861986256969
#   Std 0.45907071068236166
# -- Generation 185 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9247374562427071
#   Std 0.46236872812135354
# -- Generation 186 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170070011668612
#   Std 0.4587496353558927
# -- Generation 187 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9131417736289381
#   Std 0.45674865081680277
# -- Generation 188 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9093494749124854
#   Std 0.4549618946907818
# -- Generation 189 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9215285880980163
#   Std 0.4608736872812135
# -- Generation 190 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9183359263580965
#   Std 0.459678408657101
# -- Generation 191 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9014042294720352
#   Std 0.45088442310441995
# -- Generation 192 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9033000291715285
#   Std 0.4517776286282088
# -- Generation 193 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9235786983015688
#   Std 0.46215396512201623
# -- Generation 194 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9218320080095654
#   Std 0.4612441444497755
# -- Generation 195 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9305065311811227
#   Std 0.46557686177264745
# -- Generation 196 --
#   Evaluated 1023 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9222578763127188
#   Std 0.4611836347724621
# -- Generation 197 --
#   Evaluated 981 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9164235705950992
#   Std 0.45826648191365227
# -- Generation 198 --
#   Evaluated 1072 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9268604952677297
#   Std 0.463863234375225
# -- Generation 199 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.922407785556852
#   Std 0.46138620076404185
# -- Generation 200 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9038919681057954
#   Std 0.452219424929232
# -- Generation 201 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9146242545053804
#   Std 0.4580094273725725
# -- Generation 202 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9012705821340594
#   Std 0.4512004331611853
# -- Generation 203 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9054964021781408
#   Std 0.45329512504591807
# -- Generation 204 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9299964345909503
#   Std 0.4653628332667069
# -- Generation 205 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9055571761960327
#   Std 0.45295635210035007
# -- Generation 206 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9048355860235966
#   Std 0.4527960858099872
# -- Generation 207 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9140934947491248
#   Std 0.457256406341161
# -- Generation 208 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.904463243873979
#   Std 0.4523957117852976
# -- Generation 209 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9207263710618436
#   Std 0.46054094953325553
# -- Generation 210 --
#   Evaluated 1012 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9211639439906651
#   Std 0.460814432613769
# -- Generation 211 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9130809996110462
#   Std 0.4570874237623707
# -- Generation 212 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9104515104369245
#   Std 0.4554809779574886
# -- Generation 213 --
#   Evaluated 1003 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9183926487747958
#   Std 0.4593740883897316
# -- Generation 214 --
#   Evaluated 1015 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9088470208631931
#   Std 0.45477090748054544
# -- Generation 215 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9219702126280306
#   Std 0.4611127176835285
# -- Generation 216 --
#   Evaluated 983 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9190526546091015
#   Std 0.4596539413469953
# -- Generation 217 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9091306884480747
#   Std 0.45469296966161027
# -- Generation 218 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9098721314663555
#   Std 0.45530168053664805
# -- Generation 219 --
#   Evaluated 1020 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9167152858809802
#   Std 0.45852173278879815
# -- Generation 220 --
#   Evaluated 976 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9127082523013094
#   Std 0.45665950152250157
# -- Generation 221 --
#   Evaluated 1012 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170070011668612
#   Std 0.45877698366394404
# -- Generation 222 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9221889435910551
#   Std 0.46134515093405815
# -- Generation 223 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.93539235705951
#   Std 0.4680061032307469
# -- Generation 224 --
#   Evaluated 1065 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9160013937508102
#   Std 0.4585111476993207
# -- Generation 225 --
#   Evaluated 994 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9216096201218721
#   Std 0.4612104484942448
# -- Generation 226 --
#   Evaluated 1068 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9149649941656943
#   Std 0.45764658693115523
# -- Generation 227 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9159900492674704
#   Std 0.45817733261935106
# -- Generation 228 --
#   Evaluated 995 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170146992091274
#   Std 0.45870787840041877
# -- Generation 229 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9106002042007001
#   Std 0.4556829442276838
# -- Generation 230 --
#   Evaluated 1020 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9129306297054075
#   Std 0.45688463049575606
# -- Generation 231 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9195708544016596
#   Std 0.46029133404146333
# -- Generation 232 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9151914786723712
#   Std 0.458028728750477
# -- Generation 233 --
#   Evaluated 988 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9136559218203033
#   Std 0.4570102715686989
# -- Generation 234 --
#   Evaluated 990 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9081096849474912
#   Std 0.454164235705951
# -- Generation 235 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9136522753792299
#   Std 0.45682613768961494
# -- Generation 236 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9089888824063269
#   Std 0.4546767491887793
# -- Generation 237 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9200740632698041
#   Std 0.4602193396205179
# -- Generation 238 --
#   Evaluated 1077 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9171609620121871
#   Std 0.4588458327481019
# -- Generation 239 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9273669454168286
#   Std 0.4639032580050635
# -- Generation 240 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9200700116686115
#   Std 0.46003500583430573
# -- Generation 241 --
#   Evaluated 985 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9165694282380397
#   Std 0.45828471411901983
# -- Generation 242 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9161318553092183
#   Std 0.4582300175029172
# -- Generation 243 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9146773304810061
#   Std 0.45779445630663235
# -- Generation 244 --
#   Evaluated 994 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.919574500842733
#   Std 0.4604035519993751
# -- Generation 245 --
#   Evaluated 1001 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9149868728121353
#   Std 0.4585052554331972
# -- Generation 246 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.923801131207053
#   Std 0.4623517731551259
# -- Generation 247 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9155484247374562
#   Std 0.4579383022170362
# -- Generation 248 --
#   Evaluated 1059 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9165001458576428
#   Std 0.45866484420580506
# -- Generation 249 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9064363736548684
#   Std 0.45346886558317845
# -- Generation 250 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9205152826396991
#   Std 0.4604581701157046
# -- Generation 251 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9107501134448331
#   Std 0.45588551021926343
# -- Generation 252 --
#   Evaluated 1007 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9227063885647607
#   Std 0.46157194656140604
# -- Generation 253 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9230600933488915
#   Std 0.46170781067677946
# -- Generation 254 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9221889435910551
#   Std 0.46134515093405815
# -- Generation 255 --
#   Evaluated 1074 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9132183488914819
#   Std 0.45673678848818555
# -- Generation 256 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9248910119279138
#   Std 0.46275542799201735
# -- Generation 257 --
#   Evaluated 996 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9171727116556461
#   Std 0.45927911196442306
# -- Generation 258 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9135226241410603
#   Std 0.4572899897539505
# -- Generation 259 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.921102764812654
#   Std 0.46093421918779803
# -- Generation 260 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9249027615713729
#   Std 0.4630894429791152
# -- Generation 261 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9105361889018538
#   Std 0.45602922135765533
# -- Generation 262 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9168692467263061
#   Std 0.4588812842585388
# -- Generation 263 --
#   Evaluated 1023 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.920730017502917
#   Std 0.4607250834123395
# -- Generation 264 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9167302213040074
#   Std 0.45903965437994515
# -- Generation 265 --
#   Evaluated 1003 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9254667444574096
#   Std 0.4628974620770129
# -- Generation 266 --
#   Evaluated 1001 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.918906796966161
#   Std 0.4598271472979871
# -- Generation 267 --
#   Evaluated 1087 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8983408693115519
#   Std 0.44940744193042587
# -- Generation 268 --
#   Evaluated 992 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.915767211201867
#   Std 0.4579519763710619
# -- Generation 269 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9164272170361727
#   Std 0.4586420539490957
# -- Generation 270 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9207263710618436
#   Std 0.46054094953325553
# -- Generation 271 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.905630105017503
#   Std 0.45297914235705955
# -- Generation 272 --
#   Evaluated 1021 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9117561260210035
#   Std 0.4561515460910152
# -- Generation 273 --
#   Evaluated 982 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9234287890574354
#   Std 0.46195139913043626
# -- Generation 274 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9125016206404771
#   Std 0.45676125579829147
# -- Generation 275 --
#   Evaluated 983 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9037538085051211
#   Std 0.45235087392474993
# -- Generation 276 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9009829184493712
#   Std 0.45091072960784095
# -- Generation 277 --
#   Evaluated 1028 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9049085148450666
#   Std 0.45274685885549454
# -- Generation 278 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9202887981330222
#   Std 0.4602674664527422
# -- Generation 279 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9302909859976661
#   Std 0.46558303174226945
# -- Generation 280 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9194975204200699
#   Std 0.46029569218567673
# -- Generation 281 --
#   Evaluated 997 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9109575554259043
#   Std 0.45578415575773046
# -- Generation 282 --
#   Evaluated 1055 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.906662047841307
#   Std 0.4536591694318846
# -- Generation 283 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9157092733048101
#   Std 0.45866592153781677
# -- Generation 284 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9138054259043172
#   Std 0.4572126376531504
# -- Generation 285 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9070347951510436
#   Std 0.45427852982811295
# -- Generation 286 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9232906294567613
#   Std 0.4620828481259544
# -- Generation 287 --
#   Evaluated 1092 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9095034357578113
#   Std 0.4550580920829911
# -- Generation 288 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9111767470504343
#   Std 0.4558253781269357
# -- Generation 289 --
#   Evaluated 1084 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9134371353558925
#   Std 0.45696924910662184
# -- Generation 290 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9089925288474006
#   Std 0.45502497291617156
# -- Generation 291 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9162084305717619
#   Std 0.4584095933306593
# -- Generation 292 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9165694282380397
#   Std 0.45847615227537925
# -- Generation 293 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9117711169454168
#   Std 0.45645070858565806
# -- Generation 294 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9090686989498248
#   Std 0.45525904545288787
# -- Generation 295 --
#   Evaluated 982 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9344406359393231
#   Std 0.46747099939833714
# -- Generation 296 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.911901983663944
#   Std 0.455950991831972
# -- Generation 297 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9008168028004667
#   Std 0.4508459743290548
# -- Generation 298 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9117601776221962
#   Std 0.45611709341281664
# -- Generation 299 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9093531213535588
#   Std 0.454927242105455
# -- Generation 300 --
#   Evaluated 999 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9244566802800467
#   Std 0.4626658788834598
# -- Generation 301 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9206534422403734
#   Std 0.4603267211201867
# -- Generation 302 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9130040191883831
#   Std 0.456880299719449
# -- Generation 303 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9100216355503694
#   Std 0.4555759625422716
# -- Generation 304 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.913521813820822
#   Std 0.4573260543504293
# -- Generation 305 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9187609393232204
#   Std 0.45961747693626015
# -- Generation 306 --
#   Evaluated 1052 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9123541423570596
#   Std 0.4567422239644109
# -- Generation 307 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9109693050693635
#   Std 0.4563369572092391
# -- Generation 308 --
#   Evaluated 1019 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9180352975495915
#   Std 0.4592728768596848
# -- Generation 309 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9102392065344225
#   Std 0.45580782343932336
# -- Generation 310 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9032343932322053
#   Std 0.45212310612966744
# -- Generation 311 --
#   Evaluated 1004 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9154864352392065
#   Std 0.458249127133168
# -- Generation 312 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9111803934915077
#   Std 0.4559821636979683
# -- Generation 313 --
#   Evaluated 1012 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9076761636198625
#   Std 0.45404773810359844
# -- Generation 314 --
#   Evaluated 1054 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9128581615454427
#   Std 0.45686206751408154
# -- Generation 315 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9231330221703618
#   Std 0.46173060093348894
# -- Generation 316 --
#   Evaluated 1023 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9080408077272137
#   Std 0.4543257792354538
# -- Generation 317 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.919924154025671
#   Std 0.4602355600933489
# -- Generation 318 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9221120186697783
#   Std 0.46116540256709454
# -- Generation 319 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9183999416569428
#   Std 0.45952356968348895
# -- Generation 320 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9120555393491508
#   Std 0.45633769170263594
# -- Generation 321 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9133759561778816
#   Std 0.45708903568065107
# -- Generation 322 --
#   Evaluated 997 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9240118144690781
#   Std 0.462242914509189
# -- Generation 323 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9132147024504084
#   Std 0.4567714410735122
# -- Generation 324 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9142357059509918
#   Std 0.4571178529754959
# -- Generation 325 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9177439874238298
#   Std 0.45923661235607804
# -- Generation 326 --
#   Evaluated 1038 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9206647867237132
#   Std 0.46087932266456705
# -- Generation 327 --
#   Evaluated 992 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9089240567872422
#   Std 0.45502262650449443
# -- Generation 328 --
#   Evaluated 957 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9211679955918578
#   Std 0.4609714180919298
# -- Generation 329 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9167193374821729
#   Std 0.4587060665750104
# -- Generation 330 --
#   Evaluated 1074 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9079751717878906
#   Std 0.45447981858055303
# -- Generation 331 --
#   Evaluated 1065 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9174482205367561
#   Std 0.4590158141591307
# -- Generation 332 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9112569687540515
#   Std 0.45618908783376183
# -- Generation 333 --
#   Evaluated 985 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.912497163879165
#   Std 0.4567955085693616
# -- Generation 334 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9345828471411902
#   Std 0.4675238841890315
# -- Generation 335 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9224118371580448
#   Std 0.46157053455025415
# -- Generation 336 --
#   Evaluated 1058 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9117601776221962
#   Std 0.4560897451047653
# -- Generation 337 --
#   Evaluated 1008 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.918250842733048
#   Std 0.4595401899705763
# -- Generation 338 --
#   Evaluated 1063 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9133605600933489
#   Std 0.4567896732788798
# -- Generation 339 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9116139148191365
#   Std 0.4558798748359101
# -- Generation 340 --
#   Evaluated 1028 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9125660410994425
#   Std 0.4566066167318074
# -- Generation 341 --
#   Evaluated 976 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9120595909503435
#   Std 0.4567134636452075
# -- Generation 342 --
#   Evaluated 1010 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9193488266562945
#   Std 0.45987493945107094
# -- Generation 343 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9139480422663036
#   Std 0.457265722350973
# -- Generation 344 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9107391741216128
#   Std 0.45555189504642224
# -- Generation 345 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9178092182030338
#   Std 0.45908237310385064
# -- Generation 346 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9340763969920912
#   Std 0.46722050648166147
# -- Generation 347 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9166423570595099
#   Std 0.45849894253208867
# -- Generation 348 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9123468494749124
#   Std 0.45637395620624266
# -- Generation 349 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9149649941656943
#   Std 0.45764658693115523
# -- Generation 350 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9175904317386231
#   Std 0.45884991248541424
# -- Generation 351 --
#   Evaluated 1049 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.916058926487748
#   Std 0.45820722724620777
# -- Generation 352 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9192066154544277
#   Std 0.46004084112478766
# -- Generation 353 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9248906067677947
#   Std 0.46297401454929993
# -- Generation 354 --
#   Evaluated 1013 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9243768637365486
#   Std 0.4624938072401212
# -- Generation 355 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9191948658109685
#   Std 0.45970682613768965
# -- Generation 356 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9209451575262544
#   Std 0.4605819719953326
# -- Generation 357 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9283875437572928
#   Std 0.46432138592109096
# -- Generation 358 --
#   Evaluated 1064 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.918181155192532
#   Std 0.45929110906505244
# -- Generation 359 --
#   Evaluated 1027 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9130728964086606
#   Std 0.4567187561899462
# -- Generation 360 --
#   Evaluated 961 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9192021586931155
#   Std 0.4598563074314469
# -- Generation 361 --
#   Evaluated 984 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9124894658368987
#   Std 0.4564270409040653
# -- Generation 362 --
#   Evaluated 1009 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.912200991831972
#   Std 0.4563557240008752
# -- Generation 363 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9101626312718785
#   Std 0.45540946114717024
# -- Generation 364 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9092112598104249
#   Std 0.45506596801034166
# -- Generation 365 --
#   Evaluated 1014 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9119749124854143
#   Std 0.4561652202450409
# -- Generation 366 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9067969661610268
#   Std 0.4535625729288214
# -- Generation 367 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9070959743290548
#   Std 0.45396730509772454
# -- Generation 368 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170835764294049
#   Std 0.4589292111836347
# -- Generation 369 --
#   Evaluated 1028 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9185421528588098
#   Std 0.4595764544741832
# -- Generation 370 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9113987747957993
#   Std 0.4560229862529172
# -- Generation 371 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.908620186697783
#   Std 0.4544331607351226
# -- Generation 372 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9190526546091015
#   Std 0.4596539413469953
# -- Generation 373 --
#   Evaluated 1039 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9105965577596267
#   Std 0.45549881034859985
# -- Generation 374 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9073884999351742
#   Std 0.45400416932271614
# -- Generation 375 --
#   Evaluated 1067 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9075380040191882
#   Std 0.4542065354071677
# -- Generation 376 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9133682581356151
#   Std 0.4569393544797653
# -- Generation 377 --
#   Evaluated 943 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9205963146635551
#   Std 0.4610410661011982
# -- Generation 378 --
#   Evaluated 1068 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9298424737456242
#   Std 0.4651947199533255
# -- Generation 379 --
#   Evaluated 970 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9178821470245041
#   Std 0.4591051633605601
# -- Generation 380 --
#   Evaluated 1061 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9192025638532347
#   Std 0.45985650733857514
# -- Generation 381 --
#   Evaluated 1038 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9273669454168286
#   Std 0.46397517392623555
# -- Generation 382 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9224880072604694
#   Std 0.4617499104708682
# -- Generation 383 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9240847432905483
#   Std 0.46223835645784705
# -- Generation 384 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9130724912485414
#   Std 0.45671855628281793
# -- Generation 385 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9213940749384157
#   Std 0.4609704836914049
# -- Generation 386 --
#   Evaluated 1031 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9221156651108517
#   Std 0.4613495364461785
# -- Generation 387 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9165730746791131
#   Std 0.4584688479981038
# -- Generation 388 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9159932905484246
#   Std 0.45814248012689607
# -- Generation 389 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.907161610268378
#   Std 0.4538132657526254
# -- Generation 390 --
#   Evaluated 1020 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9177362893815636
#   Std 0.45908693115519256
# -- Generation 391 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9159167152858809
#   Std 0.4581543424555134
# -- Generation 392 --
#   Evaluated 1066 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9124927071178529
#   Std 0.456610974876021
# -- Generation 393 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9191219369894983
#   Std 0.4596840358809802
# -- Generation 394 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9212368728121354
#   Std 0.4606184364060677
# -- Generation 395 --
#   Evaluated 1062 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9260651659535849
#   Std 0.46341642393636473
# -- Generation 396 --
#   Evaluated 1064 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9164276221962919
#   Std 0.4584508156998645
# -- Generation 397 --
#   Evaluated 1054 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9232788798133023
#   Std 0.4619402712952159
# -- Generation 398 --
#   Evaluated 1041 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9069509270063529
#   Std 0.45392212439856233
# -- Generation 399 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9135145209386748
#   Std 0.4571765730566718
# -- Generation 400 --
#   Evaluated 1039 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9138102878257487
#   Std 0.45739737125361934
# -- Generation 401 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9263459419162452
#   Std 0.46340997555984115
# -- Generation 402 --
#   Evaluated 1060 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9113266562945675
#   Std 0.45621938227487496
# -- Generation 403 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9097295151043693
#   Std 0.4553205117599976
# -- Generation 404 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9119830156877998
#   Std 0.45653388781746546
# -- Generation 405 --
#   Evaluated 1010 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9056418546609621
#   Std 0.45331315734415756
# -- Generation 406 --
#   Evaluated 1010 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.911610268378063
#   Std 0.4561059655775963
# -- Generation 407 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9094260501750291
#   Std 0.45495003236216447
# -- Generation 408 --
#   Evaluated 1095 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9215322345390898
#   Std 0.4610304728522462
# -- Generation 409 --
#   Evaluated 984 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9203617269544924
#   Std 0.4602902567094515
# -- Generation 410 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9088389731621938
#   Std 0.4546929696616103
# -- Generation 411 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9059988007260469
#   Std 0.4534141689670757
# -- Generation 412 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9113226046933748
#   Std 0.45603504848866266
# -- Generation 413 --
#   Evaluated 989 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9139719467133409
#   Std 0.4577151657678863
# -- Generation 414 --
#   Evaluated 1076 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.916304453520031
#   Std 0.45910021365443615
# -- Generation 415 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9174672630623621
#   Std 0.4594993104399858
# -- Generation 416 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9275123978996499
#   Std 0.4639932062244749
# -- Generation 417 --
#   Evaluated 1069 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9057103267211202
#   Std 0.45312406559947493
# -- Generation 418 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9221849474912486
#   Std 0.4613796309801634
# -- Generation 419 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9272170361726955
#   Std 0.4637726079346558
# -- Generation 420 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.920215869311552
#   Std 0.46027202450408405
# -- Generation 421 --
#   Evaluated 1015 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9337806301050176
#   Std 0.46699970828471415
# -- Generation 422 --
#   Evaluated 1036 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9129229871645275
#   Std 0.4565161901983664
# -- Generation 423 --
#   Evaluated 1039 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9225532380396733
#   Std 0.46140423306228123
# -- Generation 424 --
#   Evaluated 1039 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9280921820303384
#   Std 0.4641007876312719
# -- Generation 425 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9202199209127446
#   Std 0.4602375718258855
# -- Generation 426 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9298424737456242
#   Std 0.4649759334889148
# -- Generation 427 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9183197199533255
#   Std 0.45915985997666275
# -- Generation 428 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9161355017502917
#   Std 0.4581953649175904
# -- Generation 429 --
#   Evaluated 960 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9172987164527421
#   Std 0.45881344807467905
# -- Generation 430 --
#   Evaluated 1045 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.8952819104109944
#   Std 0.44789618061745495
# -- Generation 431 --
#   Evaluated 1038 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9066547549591598
#   Std 0.45365645739133603
# -- Generation 432 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9228413068844807
#   Std 0.46147535005834306
# -- Generation 433 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9196364903409827
#   Std 0.4599458565400046
# -- Generation 434 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170151043692466
#   Std 0.4589268647719577
# -- Generation 435 --
#   Evaluated 1074 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9240081680280047
#   Std 0.462058780630105
# -- Generation 436 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9236556787242319
#   Std 0.4623337408568867
# -- Generation 437 --
#   Evaluated 1038 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9252520095941915
#   Std 0.463040773401148
# -- Generation 438 --
#   Evaluated 1048 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9126393750810319
#   Std 0.45662960689564497
# -- Generation 439 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9178857934655775
#   Std 0.4590705107752333
# -- Generation 440 --
#   Evaluated 971 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.912051487747958
#   Std 0.4561533579164236
# -- Generation 441 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9132228056527939
#   Std 0.45692132218152604
# -- Generation 442 --
#   Evaluated 1077 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9139480422663036
#   Std 0.457265722350973
# -- Generation 443 --
#   Evaluated 1081 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9068006126021003
#   Std 0.45352792034349476
# -- Generation 444 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9116179664203293
#   Std 0.4560642086221225
# -- Generation 445 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9066588065603527
#   Std 0.45369402192433955
# -- Generation 446 --
#   Evaluated 1006 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.918181155192532
#   Std 0.45929110906505244
# -- Generation 447 --
#   Evaluated 989 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9324063269804225
#   Std 0.4667090703308446
# -- Generation 448 --
#   Evaluated 1042 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.910455156877998
#   Std 0.45566511183657266
# -- Generation 449 --
#   Evaluated 1043 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9206615454427589
#   Std 0.46069538869261123
# -- Generation 450 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9092036172695449
#   Std 0.4547248760210035
# -- Generation 451 --
#   Evaluated 1051 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9219698074679112
#   Std 0.46111251777640017
# -- Generation 452 --
#   Evaluated 1055 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9054113185530922
#   Std 0.4529381198949825
# -- Generation 453 --
#   Evaluated 1040 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9064359684947491
#   Std 0.4534686656760501
# -- Generation 454 --
#   Evaluated 1035 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9183197199533255
#   Std 0.45937864644107346
# -- Generation 455 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9191948658109685
#   Std 0.4599256126021004
# -- Generation 456 --
#   Evaluated 1047 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9119060352651367
#   Std 0.4561353256181842
# -- Generation 457 --
#   Evaluated 1033 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.90373760210035
#   Std 0.45219788096193114
# -- Generation 458 --
#   Evaluated 1010 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9145310676779462
#   Std 0.45755723772972573
# -- Generation 459 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.915552476338649
#   Std 0.4580952876951971
# -- Generation 460 --
#   Evaluated 1005 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9199282056268637
#   Std 0.46020110741515047
# -- Generation 461 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.917760193828601
#   Std 0.4595363745721058
# -- Generation 462 --
#   Evaluated 1101 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9172987164527421
#   Std 0.4587769836639439
# -- Generation 463 --
#   Evaluated 1010 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9223389083365745
#   Std 0.46176653075795543
# -- Generation 464 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9116872488007259
#   Std 0.45609430315610716
# -- Generation 465 --
#   Evaluated 993 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.904612747957993
#   Std 0.4523792914053384
# -- Generation 466 --
#   Evaluated 1028 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9154795475171787
#   Std 0.45807249743848766
# -- Generation 467 --
#   Evaluated 1039 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9235017178789057
#   Std 0.4621656275435051
# -- Generation 468 --
#   Evaluated 1037 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9089961752884739
#   Std 0.45482623048253656
# -- Generation 469 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9185462044600025
#   Std 0.45954200179598464
# -- Generation 470 --
#   Evaluated 1063 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9207377155451836
#   Std 0.4608747646132253
# -- Generation 471 --
#   Evaluated 1104 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9064363736548684
#   Std 0.4536876520475892
# -- Generation 472 --
#   Evaluated 1044 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9208029463243873
#   Std 0.4607205253609976
# -- Generation 473 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9216744457409568
#   Std 0.4608919194865811
# -- Generation 474 --
#   Evaluated 1056 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9148227829638272
#   Std 0.45759370214046086
# -- Generation 475 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9164235705950992
#   Std 0.45848526837806297
# -- Generation 476 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170110527680538
#   Std 0.45874253098574547
# -- Generation 477 --
#   Evaluated 1017 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9135833981589524
#   Std 0.4572064676835285
# -- Generation 478 --
#   Evaluated 1029 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9108850317645533
#   Std 0.4557615654081492
# -- Generation 479 --
#   Evaluated 1006 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9170146992091274
#   Std 0.4591181030211889
# -- Generation 480 --
#   Evaluated 1057 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9101715447945025
#   Std 0.45599731499826196
# -- Generation 481 --
#   Evaluated 1011 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.910597368079865
#   Std 0.4557179966272669
# -- Generation 482 --
#   Evaluated 1023 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9107391741216128
#   Std 0.45555189504642224
# -- Generation 483 --
#   Evaluated 1002 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9059254667444574
#   Std 0.4533638304951867
# -- Generation 484 --
#   Evaluated 1016 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9092036172695449
#   Std 0.45494366248541424
# -- Generation 485 --
#   Evaluated 994 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9157023855827822
#   Std 0.4583252019948282
# -- Generation 486 --
#   Evaluated 986 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9189910702709712
#   Std 0.460156404326615
# -- Generation 487 --
#   Evaluated 1030 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9195595099183197
#   Std 0.45995751896149356
# -- Generation 488 --
#   Evaluated 1032 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9216780921820303
#   Std 0.46107605336566515
# -- Generation 489 --
#   Evaluated 1046 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9260619246726306
#   Std 0.46330440588558097
# -- Generation 490 --
#   Evaluated 1025 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9148993582263709
#   Std 0.45777327796820294
# -- Generation 491 --
#   Evaluated 1024 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9191989174121612
#   Std 0.45989115992390184
# -- Generation 492 --
#   Evaluated 1000 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9154143167379748
#   Std 0.4579988341236206
# -- Generation 493 --
#   Evaluated 1022 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9101516919486581
#   Std 0.45507584597432904
# -- Generation 494 --
#   Evaluated 1028 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9093531213535588
#   Std 0.454927242105455
# -- Generation 495 --
#   Evaluated 1018 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9178934915078438
#   Std 0.4592201919761189
# -- Generation 496 --
#   Evaluated 1038 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9208722287047841
#   Std 0.4605591817386231
# -- Generation 497 --
#   Evaluated 992 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9157023855827822
#   Std 0.4581064155304175
# -- Generation 498 --
#   Evaluated 1034 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9011897237502546
#   Std 0.45102784698286996
# -- Generation 499 --
#   Evaluated 1026 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9158437864644107
#   Std 0.4580868832956534
# -- Generation 500 --
#   Evaluated 1050 individuals
#   Min 0.0
#   Max 1.0
#   Avg 0.9231330221703618
#   Std 0.46173060093348894
# -- End of (successful) evolution --
#
#
# -- Final Population --

# %%
display(df_hasil.head())
# Out:
#    antecedents  ... kulczynski
# 0  [8, 78, 96]  ...        1.0
# 1  [8, 78, 96]  ...        1.0
# 2  [8, 78, 96]  ...        1.0
# 3  [8, 78, 96]  ...        1.0
# 4  [8, 78, 96]  ...        1.0
#
# [5 rows x 4 columns]

# %%
print('Nilai fitness minimum pada populasi sebelum GA %s' %round(mins[0], 4))
print('Nilai fitness minimum pada populasi setelah GA %s' %round(mins[-1], 4))
        
print("Nilai fitness maksimum pada populasi sebelum GA %s" %round(maxs[0], 4))
print("Nilai fitness maksimum pada populasi setelah GA %s" %round(maxs[-1], 4))
        
print("Rata-rata nilai fitness pada populasi sebelum GA %s" %round(means[0], 4))
print("Rata-rata nilai fitness pada populasi setelah GA %s" %round(means[-1], 4))
        
print("Standar deviasi nilai fitness pada populasi sebelum GA %s" %round(stds[0], 4))
print("Standar deviasi nilai fitness pada populasi setelah GA %s" %round(stds[-1], 4))
# Out:
# Nilai fitness minimum pada populasi sebelum GA 0.0212
# Nilai fitness minimum pada populasi setelah GA 0.0
# Nilai fitness maksimum pada populasi sebelum GA 0.1165
# Nilai fitness maksimum pada populasi setelah GA 1.0
# Rata-rata nilai fitness pada populasi sebelum GA 0.0334
# Rata-rata nilai fitness pada populasi setelah GA 0.9231
# Standar deviasi nilai fitness pada populasi sebelum GA 0.0328
# Standar deviasi nilai fitness pada populasi setelah GA 0.4617

# %%
# hapus aturan asosiasi yang duplikat
df_hasil['new'] = df_hasil.chromosome.apply(tuple)
df_hasil_akhir = df_hasil.sort_values('kulczynski', ascending=False).drop_duplicates('new').drop(['new'], axis=1)
df_hasil_akhir = df_hasil_akhir[df_hasil_akhir["kulczynski"] != 0.00].reset_index(drop=True)

# hapus aturan asosiasi dengan nilai antecedent / consequent yang hilang
# atau dengan item lebih dari satu pada antecedent / consequent
for id, baris in df_hasil_akhir.iterrows():
    if len(baris['antecedents']) == 0 or len(baris['consequents']) == 0:
        df_hasil_akhir.drop(id, inplace=True)

# %%
display(df_hasil_akhir.head())
# Out:
#    antecedents  ... kulczynski
# 0  [8, 78, 96]  ...       1.00
# 1  [8, 50, 96]  ...       1.00
# 2  [8, 50, 78]  ...       1.00
# 3  [8, 62, 78]  ...       1.00
# 4     [78, 96]  ...       0.75
#
# [5 rows x 4 columns]

# %%
# Periksa aturan asosiasi apakah anteseden mengandung semua restoran
# yang ada pada set data
for i in range(100):
    if [i+1] in df_hasil_akhir['antecedents'].tolist() == False:
        print(i+1, " tidak ada")

# %%
def lookup_item(k):
    return list(restaurant_replace_map_comp.keys())[list(restaurant_replace_map_comp.values()).index(k)]

for baris in df_hasil_akhir.itertuples():
    print("Aturan Asosiasi #{0}".format(baris.Index + 1))
    (premise, conclusion) = (baris.antecedents, baris.consequents)
    premise_names = ", ".join(lookup_item(elemen) for elemen in premise)
    conclusion_names = ", ".join(lookup_item(elemen) for elemen in conclusion)
    print("Aturan Asosiasi: Jika seseorang merekomendasi {0}, maka ia juga akan merekomendasi {1}".format(premise_names, conclusion_names))
    print(" - Kulczynski: {0:.2f}".format(baris.kulczynski))
    print("\n")
# Out:
# Aturan Asosiasi #1
# Aturan Asosiasi: Jika seseorang merekomendasi Amul, Shanghai Chef 2, Urban Asia - Kitchen & Bar, maka ia juga akan merekomendasi Karachi Bakery, Mustang Terrace Lounge
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #2
# Aturan Asosiasi: Jika seseorang merekomendasi Amul, Karachi Bakery, Urban Asia - Kitchen & Bar, maka ia juga akan merekomendasi Mustang Terrace Lounge, Shanghai Chef 2
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #3
# Aturan Asosiasi: Jika seseorang merekomendasi Amul, Karachi Bakery, Shanghai Chef 2, maka ia juga akan merekomendasi Mustang Terrace Lounge, Urban Asia - Kitchen & Bar
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #4
# Aturan Asosiasi: Jika seseorang merekomendasi Amul, Mustang Terrace Lounge, Shanghai Chef 2, maka ia juga akan merekomendasi Karachi Bakery, Urban Asia - Kitchen & Bar
#  - Kulczynski: 1.00
#
#
# Aturan Asosiasi #5
# Aturan Asosiasi: Jika seseorang merekomendasi Shanghai Chef 2, Urban Asia - Kitchen & Bar, maka ia juga akan merekomendasi Karachi Bakery, Mustang Terrace Lounge
#  - Kulczynski: 0.75
#
#
# Aturan Asosiasi #6
# Aturan Asosiasi: Jika seseorang merekomendasi Amul, Shanghai Chef 2, maka ia juga akan merekomendasi Karachi Bakery, Mustang Terrace Lounge
#  - Kulczynski: 0.75

# %% [markdown]
# ## 6. Rekomendasi Restoran

# %%
def lookup_id_restoran(nama_restoran):
    return int(restaurant_replace_map_comp.get(nama_restoran))

def rekomendasi_restoran(id_restoran_prefensi):
    list_temp = []

    for indeks, baris in df_hasil_akhir.iterrows():
        if id_restoran_prefensi in baris['antecedents']:
            list_temp.append(baris)
    df_extract = pd.DataFrame(list_temp,
                           columns = ['antecedents',
                                      'consequents',
                                      'chromosome',
                                      'kulczynski']).reset_index(drop=True)
    
    # sortir baris pada df_extract berdasarkan kolom kulczynski
    df_extract = df_extract.sort_values('kulczynski', ascending=False)
    
    # pilih aturan asosiasi top 3
    # df_extract = df_extract.head(3)

    # kombinasikan setiap item pada consequent
    list_top_restaurant = []
    for i in df_extract['consequents']:
        list_top_restaurant = list_top_restaurant + i

    list_rekomendasi = []
    for i in list_top_restaurant:
        list_rekomendasi = list_rekomendasi + [lookup_item(i)]

    return list(dict.fromkeys(list_rekomendasi))

# %%
# print('Masukkan restoran preferensi:')
x = input('')
print('Rekomendasi adalah', rekomendasi_restoran(lookup_id_restoran(x)))
# Out:
# Shanghai Chef 2
# Rekomendasi adalah ['Karachi Bakery', 'Mustang Terrace Lounge', 'Urban Asia - Kitchen & Bar']
